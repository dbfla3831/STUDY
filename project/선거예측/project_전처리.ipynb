# %% [markdown]
# # 라이브러리 불러오기

# %%
import pandas as pd

# %% [markdown]
# # 데이터 불러오기

# %%
df_2012 = pd.read_csv('2012_news.csv')
df_2012
# Out:
#                                               title  \
# 0                                  ‘버핏세 반란’에 밀린 박근혜
# 1                                김창수 의원도 탈당…위기의 선진당
# 2                                첫 부자증세지만 ‘무늬만 버핏세’
# 3                           여야 ‘방송광고판매대행법’ 5일 처리 예정
# 4                          사실상 ‘박근혜 예산’ 한나라당, 단독 처리
# ...                                             ...
# 28426                        이외수 “새누리 후보 지지” 트위터 발칵
# 28427               이혜훈 "투표율 올라가면 보수층 몰려 새누리당 유리하다"
# 28428                      세종시 총선, ‘이해찬 막말 파문’의 결과는
# 28429  [총선 D-1]박근혜, 한명숙의 선택은? '수도권 릴레이' vs '대학가 공략'
# 28430                         총선 D-1, 여야 수도권 공략 총력전
#
#                                                  content
# 0      [한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위...
# 1      [한겨레]  자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다.  대전 대덕 출...
# 2      ㆍ세수 증가 효과는 제한적… 정부 감세정책 ‘벼랑 끝’과세표준 3억원 초과 구간에 ...
# 3      ㆍ여당 요구 대폭 수용 ‘반쪽’종합편성채널(종편)의 직접 광고 영업을 막는 ‘방송광...
# ...

# %%
df_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28431 entries, 0 to 28430
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    28431 non-null  object
#  1   content  28431 non-null  object
# dtypes: object(2)
# memory usage: 444.4+ KB

# %%
df_2012['content'][1001]
# Out:
# '與, KBS 수신료 관련 소위 구성안 기습처리[CBS 김재덕 기자] 방송광고시장의 안정을 위한 미디어렙법(방송광고판매대행사법)이 극심한 진통속에 5일 국회 문화체육관광방송통신위원회를 통과했다.미디어렙법이 상임위를 통과함에 따라 이제 본회의 통과만을 남겨두게 됐다.이에 따라 지난 2008년 11월 헌법재판소가 코바코의 방송광고독점 판매에 대해 헌법불합치 결정을 내린 이후 3년여만에 입법공백상태가 해소될 가능성이 높아졌다.여야는 미디어렙법 처리를 위해 오는 13일 본회의를 소집하는 방안을 검토하고 있다.이날 미디어렙법안의 문방위 처리는 한나라당이 KBS 수신료 인상 문제를 연계하면서 하루 종일 파행을 거듭한 끝에 오후 10시 55분쯤에야 처리됐다.문방위는 당초 오전 10시 열릴 예정이었으나 한나라당 의원들이 KBS 수신료 문제에 대한 대응책을 논의하느라 정오가 돼서야 시작됐다.회의가 시작되자마자 한나라당 의원들은 돌연 KBS 수신료 인상 문제를 미디어렙법과 연계시키고 나섰다.심재철 의원은 의사진행발언을 통해 "KBS 수신료 인상 승인안과 지배구조 개선, 수신료 산정위원회 구성 등을 보다 심도있게 논의해 2월 임시국회에서 처리할 것을 목표로 소위를 구성하는 문제를 미디어렙법과 동일하게 논의"하자고 제안했고, 전재희 위원장은 즉시 국회법 조항을 들어 동의자 외 1인 이상의 찬성으로 의제가 될 수 있다며 의제가 됐음을 선포했다.이에 민주통합당 의원들은 여야 간사간에 협의도 없었고 안건에도 없었던 수신료 인상문제를 의제로 기습상정한 것은 미디어렙법 처리를 무산시키려는 의도라며 강력히 반발했다.김재윤 의원은 "미디어렙법과 전혀 관계없는 수신료 인상건을 들고나온 저의가 드러났다"며 "미디어렙법 처리를 저지하려 할 경우 국민적 저항에 직면할 것"이라고 경고했다. 전병헌 의원은 "중소방송을 볼모로 수신료 인상건을 연계처리하려 한다"며 "이는 종편 방송정책 실패의 부담을 준조세 형태의 수신료로 전가시키겠다는 의도"라고 강력히 비판했다.허원제 안형환 의원 등 한나라당 의원들은
# ...

# %%
df_2012['content'][10001]
# Out:
# '(서울=연합뉴스) 서명곤 기자 = 새누리당 김종인 비대위원이 8일 오전 국회 새누리당 정책위의장실에서 열린 비대위 정책쇄신분과회의에서 모두발언을 하고 있다. 김종인 비대위원은 회의에서 "정책쇄신분과위를 오늘까지만 운영하고 당분간 회의를 하지 않으려 한다"고 밝혔다.   2012.2.8 seephoto@yna.co.kr[이 시각 인기 기사]☞<"왜 全 전대통령 경호동만 갖고 그래?">  ☞김재균, 전두환ㆍ노태우 前 대통령 경호중단 추진  ☞<박근혜 3차례 눈물..의원들 "대승적 결단">  ☞새누리, 黨 심벌ㆍ로고ㆍ상징색 확정  ☞<美NBC방송, 슈퍼볼 방송사고 제재받을까>  <연합뉴스 모바일앱 다운받기> <포토 매거진><저작권자(c)연합뉴스. 무단전재-재배포금지.>'

# %%
text_test = df_2012['content'].iloc[0]
text_test
# Out:
# '[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위상’ 드러나 한나라당 안에서 ‘박근혜의 뜻’에 브레이크가 걸렸다. 박근혜 비상대책위원장이 부정적인 뜻을 나타낸 소득세 최고구간 신설안(일명 버핏세)이 결국 여야 합의로 지난달 31일 국회 본회의에서 처리됐기 때문이다.  서울의 한 의원은 “부자증세도 의미가 있지만 한나라당에서 박근혜 위원장 뜻대로 안 되는 일이 있다는 걸 알려준 의미가 더 크다”고 말했다. 한나라당 일부 의원들이 박근혜 위원장의 뜻을 거슬러 야당과 공동으로 소득세법 개정안 수정안을 제출한 것 자체가 박 위원장의 변화된 당내 위상을 반영한다는 해석이다. 정두언 의원은 지난 31일 의총에서 “왜 다수 의원이 바라는 데 박 비대위원장이 일방적으로 안 된다고 하느냐. 이렇게 밀어붙이면 탈당하겠다”며 박 위원장을 압박한 것으로 알려졌다. 박 위원장은 이날 밤 열린 본회의에서 소득세 최고구간 신설 표결에 참여하지 않으며 불편한 심기를 표시했다. 박 위원장은 자본소득 과세 강화 등을 포함하는 부자증세 방안을 총선 공약으로 제시할 계획이었지만 소득세 최고구간 신설로 정책수정이 불가피해졌다. 한 서울 초선 의원은 “자신이 거부한 안이 다시 튀어나와 통과된 셈이다. 이젠 특정인이 대세를 막을 수 없다는 게 증명된 것”이라며 “박 위원장으로선 아픈 대목일 것”이라고 말했다. 정두언 의원은 이날 자신의 트위터에 “박근혜 체제에서 부정적으로 바뀐 기류를 되살리느나 혼신의 힘을 다했다. 민심을 업으면 어떤 벽도 넘을 수 있다는 사실을 다시 확인했다”고 글을 올렸다.  당내에선 박 위원장 중심의 비대위에 대한 불만이 소득세 최고구간 표결에 반영된 것이란 분석도 나온다. 실제 31일 의총에선 친이계인 권택기, 장제원, 권성동 의원 등이 김종인 비대위원과 이상돈 비대위원에 대해 각각 과거 동화은행 뇌물수수 사건으로 유죄판결을 받았다는 점과 천안함 사건 직후 북한 소행 가능성을 배제했다는 점을 들어 사퇴를 요구했다. 그러나 김종인 위원은 
# ...

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# ## 문장 토큰화

# %%
from nltk import sent_tokenize
import nltk
#nltk.download('punkt')

text_test = df_2012['content'].iloc[0]
sentences = sent_tokenize(text=text_test)
sentences
# Out:
# ['[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위상’ 드러나 한나라당 안에서 ‘박근혜의 뜻’에 브레이크가 걸렸다.',
#  '박근혜 비상대책위원장이 부정적인 뜻을 나타낸 소득세 최고구간 신설안(일명 버핏세)이 결국 여야 합의로 지난달 31일 국회 본회의에서 처리됐기 때문이다.',
#  '서울의 한 의원은 “부자증세도 의미가 있지만 한나라당에서 박근혜 위원장 뜻대로 안 되는 일이 있다는 걸 알려준 의미가 더 크다”고 말했다.',
#  '한나라당 일부 의원들이 박근혜 위원장의 뜻을 거슬러 야당과 공동으로 소득세법 개정안 수정안을 제출한 것 자체가 박 위원장의 변화된 당내 위상을 반영한다는 해석이다.',
#  '정두언 의원은 지난 31일 의총에서 “왜 다수 의원이 바라는 데 박 비대위원장이 일방적으로 안 된다고 하느냐.',
#  '이렇게 밀어붙이면 탈당하겠다”며 박 위원장을 압박한 것으로 알려졌다.',
#  '박 위원장은 이날 밤 열린 본회의에서 소득세 최고구간 신설 표결에 참여하지 않으며 불편한 심기를 표시했다.',
#  '박 위원장은 자본소득 과세 강화 등을 포함하는 부자증세 방안을 총선 공약으로 제시할 계획이었지만 소득세 최고구간 신설로 정책수정이 불가피해졌다.',
#  '한 서울 초선 의원은 “자신이 거부한 안이 다시 튀어나와 통과된 셈이다.',
#  '이젠 특정인이 대세를 막을 수 없다는 게 증명된 것”이라며 “박 위원장으로선 아픈 대목일 것”이라고 말했다.',
#  '정두언 의원은 이날 자신의 트위터에 “박근혜 체제에서 부정적으로 바뀐 기류를 되살리느나 혼신의 힘을 다했다.',
#  '민심을 업으면 어떤 벽도 넘을 수 있다는 사실을 다시 확인했다”고 글을 올렸다.',
#  '당내에선 박 위원장 중심의 비대위에 대한 불만이 소득세 최고구간 표결에 반영된 것이란 분석도 나온다.',
# ...

# %%
## 문장 토큰화한 데이터를 데이터프레임에 저장
from tqdm import tqdm
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

test = df_2012[:5]


# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
test['sentences'] = test['content'].apply(tokenize_sentences)

# 결과 확인
test
# Out:
# /var/folders/gj/cw0gqntn3wdg732bpmw8zv3c0000gn/T/ipykernel_3066/335692580.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['sentences'] = test['content'].apply(tokenize_sentences)
#                       title  \
# 0          ‘버핏세 반란’에 밀린 박근혜
# 1        김창수 의원도 탈당…위기의 선진당
# 2        첫 부자증세지만 ‘무늬만 버핏세’
# 3   여야 ‘방송광고판매대행법’ 5일 처리 예정
# 4  사실상 ‘박근혜 예산’ 한나라당, 단독 처리
#
#                                              content  \
# 0  [한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위...
# 1  [한겨레]  자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다.  대전 대덕 출...
# 2  ㆍ세수 증가 효과는 제한적… 정부 감세정책 ‘벼랑 끝’과세표준 3억원 초과 구간에 ...
# 3  ㆍ여당 요구 대폭 수용 ‘반쪽’종합편성채널(종편)의 직접 광고 영업을 막는 ‘방송광...
# 4  ㆍ4년간 한번도 합의처리 못해2012년 예산안이 사실상 한나라당 단독 처리로 국회를...
#
# ...

# %%
test['sentences'].iloc[1]
# Out:
# ['[한겨레]  자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다.',
#  '대전 대덕 출신 김창수 의원은 지난 31일 “정권 교체를 위한 야권대통합과 한반도 평화세력의 대동단결을 위해 정치적인 고향인 민주통합당에 복귀하겠다”며 자유선진당 탈당을 선언했다.',
#  '2000년 새천년민주당 창당 발기인으로 참여한 김 의원은 “당이 김정일 사망 국면에서 수구보수적인 대북정책으로 일관하는 데 실망했다”고 말했다.',
#  '문정림 선진당 대변인은 논평에서 “국회 재입성을 위해, 하루아침에 소신과 명분을 달리 표현하는 양면 모습이 안타깝기만 하다”고 비판했다.',
#  '앞서 29일엔 대전 유성출신으로 17대 땐 열린우리당 소속이던 이상민 의원이 민주통합당 입당을 선언하며 탈당했고, 지난달 1일엔 충북 보은·옥천·영동 출신인 이용희 의원이 탈당해 민주통합당에 입당했다.',
#  '2008년 4월 총선에서 18석을 얻으며 그해 8월 창조한국당과 교섭단체까지 꾸리기도 했던 선진당은 의석이 15석으로 줄면서 창당 이래 최대 위기를 맞게 됐다.',
#  '선진당은 이용희 의원의 탈당으로 충북엔 의석이 없어지면서 ‘충청권 맹주’라는 말도 무색하게 됐다.',
#  '선진당의 위기는 예견된 것이란 평이 많다.',
#  '선진당은 전국 정당화를 내걸었지만 지역주의에서 벗어나지 못했다는 평가가 적지 않다.',
#  '지난해 11월 심대평 대표와 이명박 대통령의 비밀회동 사실이 알려지며 야당으로서의 정체성에 치명상을 입기도 했다.',
#  '지난해 26~27일 실시한 <한겨레>-한국사회여론조사연구소(KSOI) 여론조사에서 선진당은 대전·충청 지역에서 4.2%의 지지를 얻어 민주통합당(31.0%)과 한나라당(26.0%)에 크게 못미쳤다.',
# ...

# %%
df_2012 = pd.read_csv('2012_news.csv')

# %%
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
df_2012['sentences'] = df_2012['content'].apply(tokenize_sentences)
df_2012['sentences'] = df_2012['sentences'].apply(lambda x: x[:-1] if x else [])
df_2012 = df_2012.drop('content', axis=1)

# 결과 확인
df_2012
# Out:
#                                               title  \
# 0                                  ‘버핏세 반란’에 밀린 박근혜
# 1                                김창수 의원도 탈당…위기의 선진당
# 2                                첫 부자증세지만 ‘무늬만 버핏세’
# 3                           여야 ‘방송광고판매대행법’ 5일 처리 예정
# 4                          사실상 ‘박근혜 예산’ 한나라당, 단독 처리
# ...                                             ...
# 28426                        이외수 “새누리 후보 지지” 트위터 발칵
# 28427               이혜훈 "투표율 올라가면 보수층 몰려 새누리당 유리하다"
# 28428                      세종시 총선, ‘이해찬 막말 파문’의 결과는
# 28429  [총선 D-1]박근혜, 한명숙의 선택은? '수도권 릴레이' vs '대학가 공략'
# 28430                         총선 D-1, 여야 수도권 공략 총력전
#
#                                                sentences
# 0      [[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 ...
# 1      [[한겨레]  자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다., 대전 대덕 ...
# 2      [ㆍ세수 증가 효과는 제한적… 정부 감세정책 ‘벼랑 끝’과세표준 3억원 초과 구간에...
# 3      [ㆍ여당 요구 대폭 수용 ‘반쪽’종합편성채널(종편)의 직접 광고 영업을 막는 ‘방송...
# ...

# %%
df_2012['sentences'][100][-1]
# Out:
# '2012.1.1 seephoto@yna.co.kr<연합뉴스 모바일앱 다운받기> <포토 매거진><저작권자(c)연합뉴스.'

# %%
df_2012['last_sentences'] = df_2012['sentences'].apply(lambda x: x[-1] if x else [])
df_2012['last_sentences'].iloc[1]
# Out:
# '지난해 26~27일 실시한 <한겨레>-한국사회여론조사연구소(KSOI) 여론조사에서 선진당은 대전·충청 지역에서 4.2%의 지지를 얻어 민주통합당(31.0%)과 한나라당(26.0%)에 크게 못미쳤다.'

# %%
df_2012['sentences'][1]
# Out:
# ['[한겨레]  자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다.',
#  '대전 대덕 출신 김창수 의원은 지난 31일 “정권 교체를 위한 야권대통합과 한반도 평화세력의 대동단결을 위해 정치적인 고향인 민주통합당에 복귀하겠다”며 자유선진당 탈당을 선언했다.',
#  '2000년 새천년민주당 창당 발기인으로 참여한 김 의원은 “당이 김정일 사망 국면에서 수구보수적인 대북정책으로 일관하는 데 실망했다”고 말했다.',
#  '문정림 선진당 대변인은 논평에서 “국회 재입성을 위해, 하루아침에 소신과 명분을 달리 표현하는 양면 모습이 안타깝기만 하다”고 비판했다.',
#  '앞서 29일엔 대전 유성출신으로 17대 땐 열린우리당 소속이던 이상민 의원이 민주통합당 입당을 선언하며 탈당했고, 지난달 1일엔 충북 보은·옥천·영동 출신인 이용희 의원이 탈당해 민주통합당에 입당했다.',
#  '2008년 4월 총선에서 18석을 얻으며 그해 8월 창조한국당과 교섭단체까지 꾸리기도 했던 선진당은 의석이 15석으로 줄면서 창당 이래 최대 위기를 맞게 됐다.',
#  '선진당은 이용희 의원의 탈당으로 충북엔 의석이 없어지면서 ‘충청권 맹주’라는 말도 무색하게 됐다.',
#  '선진당의 위기는 예견된 것이란 평이 많다.',
#  '선진당은 전국 정당화를 내걸었지만 지역주의에서 벗어나지 못했다는 평가가 적지 않다.',
#  '지난해 11월 심대평 대표와 이명박 대통령의 비밀회동 사실이 알려지며 야당으로서의 정체성에 치명상을 입기도 했다.',
#  '지난해 26~27일 실시한 <한겨레>-한국사회여론조사연구소(KSOI) 여론조사에서 선진당은 대전·충청 지역에서 4.2%의 지지를 얻어 민주통합당(31.0%)과 한나라당(26.0%)에 크게 못미쳤다.']

# %%
import re
from tqdm import tqdm

# 새로운 열을 생성하기 위해 빈 리스트 초기화
new_content = []

for i in tqdm(range(len(df_2012['sentences']))):
    res = []
    if df_2012['sentences'][i]:
        for j in range(len(df_2012['sentences'][i])):
            if not (re.search("[a-zA-Z]", df_2012['sentences'][i][j][-1]) or '@' in df_2012['sentences'][i][j][-1] or '<' in df_2012['sentences'][i][j][-1] or '>' in df_2012['sentences'][i][j][-1]):
                res.append(df_2012['sentences'][i][j][:-1])
            else:
                res.append(df_2012['sentences'][i][j])
    # 각 행에 대한 결과를 빈 리스트에 추가
    new_content.append(res)

# 새로운 열로 할당
df_2012['new_content'] = new_content
# Out:
# 100%|██████████████████████████████████| 28431/28431 [00:01<00:00, 16126.87it/s]

# %%
df_2012['new_content'][3]
# Out:
# ['ㆍ여당 요구 대폭 수용 ‘반쪽’종합편성채널(종편)의 직접 광고 영업을 막는 ‘방송광고판매대행법’의 처리가 2012년으로 넘겨졌다',
#  '여야의 의견 다툼으로 국회 문화체육관광방송통신위원회는 1일 새벽 법안심사소위를 열어 법안을 의결했지만 상임위 전체회의를 열기에는 의결정족수가 부족했다.문방위 법안소위를 통과한 ‘방송광고판매대행법’은 한나라당 뜻대로 ‘1사 1대행사’ 체제로 관철됐다',
#  '종편을 방송광고판매대행 틀 안에 편입하되 채널별로 2014년 3~5월까지 적용이 유예된다',
#  '유예기간엔 종편들이 직접 광고 영업을 할 수 있게 된다.앞서 문방위 소위에서 격돌한 쟁점은 두 가지다',
#  '민영 대행사를 ‘2사 1대행사’로 할지, ‘1사 1대행사’로 할지가 관건이었다',
#  '한나라당은 ‘1사 1대행사’로 종편이 따로 대행사를 가질 수 있도록 해야 한다고 주장했고, 민주통합당은 광고판매대행사에 2개사 이상이 들어가도록 요구했다.민주통합당이 종편의 대행사 편입 유예기간을 ‘개국(2011년 12월) 이후 2년’으로 한 데 반해, 한나라당은 ‘종편사업자 승인(2011년 3~5월) 이후 3년’으로 맞섰다.접점 없이 평행선을 가면서 결국 지난달 31일 본회의 처리는 물 건너갔다',
#  '막판에 극적으로 타협하면서 문방위는 5일 전체회의를 열어 법안을 통과시킬 예정이다',
#  '하지만 결론적으로 민주통합당이 한나라당 주장을 모두 용인하면서 반쪽짜리 법안이라는 비판에 직면하게 됐다',
#  '종편이 자사의 대행사를 갖게 되고 법의 적용을 받지 않는 유예기간도 4~6개월 더 챙기게 됐다.<박홍두 기자 phd@kyunghyang.com>경향신문 ‘오늘의 핫뉴스’  ▶ 자살 여중생, 담임교사 책상에… ▶ 6살 소녀, 해변서 수천만원짜리 조개 발견▶ 박근혜, 김제동과 만나 무슨 얘기…▶ 25세 김선주씨, 빚에 몰려 카드 돌려막기 ▶ 10대, 남친관계·화장… 엄마에겐 말 안해요  모바일 경향 [New 아이폰 App 다운받기!']

# %%
df_2012['new_content'][3]
# Out:
# ['ㆍ여당 요구 대폭 수용 ‘반쪽’종합편성채널(종편)의 직접 광고 영업을 막는 ‘방송광고판매대행법’의 처리가 2012년으로 넘겨졌다',
#  '여야의 의견 다툼으로 국회 문화체육관광방송통신위원회는 1일 새벽 법안심사소위를 열어 법안을 의결했지만 상임위 전체회의를 열기에는 의결정족수가 부족했다.문방위 법안소위를 통과한 ‘방송광고판매대행법’은 한나라당 뜻대로 ‘1사 1대행사’ 체제로 관철됐다',
#  '종편을 방송광고판매대행 틀 안에 편입하되 채널별로 2014년 3~5월까지 적용이 유예된다',
#  '유예기간엔 종편들이 직접 광고 영업을 할 수 있게 된다.앞서 문방위 소위에서 격돌한 쟁점은 두 가지다',
#  '민영 대행사를 ‘2사 1대행사’로 할지, ‘1사 1대행사’로 할지가 관건이었다',
#  '한나라당은 ‘1사 1대행사’로 종편이 따로 대행사를 가질 수 있도록 해야 한다고 주장했고, 민주통합당은 광고판매대행사에 2개사 이상이 들어가도록 요구했다.민주통합당이 종편의 대행사 편입 유예기간을 ‘개국(2011년 12월) 이후 2년’으로 한 데 반해, 한나라당은 ‘종편사업자 승인(2011년 3~5월) 이후 3년’으로 맞섰다.접점 없이 평행선을 가면서 결국 지난달 31일 본회의 처리는 물 건너갔다',
#  '막판에 극적으로 타협하면서 문방위는 5일 전체회의를 열어 법안을 통과시킬 예정이다',
#  '하지만 결론적으로 민주통합당이 한나라당 주장을 모두 용인하면서 반쪽짜리 법안이라는 비판에 직면하게 됐다',
#  '종편이 자사의 대행사를 갖게 되고 법의 적용을 받지 않는 유예기간도 4~6개월 더 챙기게 됐다.<박홍두 기자 phd@kyunghyang.com>경향신문 ‘오늘의 핫뉴스’  ▶ 자살 여중생, 담임교사 책상에… ▶ 6살 소녀, 해변서 수천만원짜리 조개 발견▶ 박근혜, 김제동과 만나 무슨 얘기…▶ 25세 김선주씨, 빚에 몰려 카드 돌려막기 ▶ 10대, 남친관계·화장… 엄마에겐 말 안해요  모바일 경향 [New 아이폰 App 다운받기!']

# %%
df_2012['last_sentences'][10]
# Out:
# '지역구 의원들이 계소조정소위 위원들에게 예산 반영을 요청하는 이른바 ‘민원성 쪽지’도 2000건이 넘었다고 한다.<박홍두 기자 phd@kyunghyang.com>[관련기사]▶ 사실상 ‘박근혜 예산’ 한나라당, 단독 처리▶ 복지예산 28.2%…정부안보다 6676억 늘어 모바일 경향 [New 아이폰 App 다운받기!]'

# %%
df_2012['sentences'].iloc[1]
# Out:
# ['[한겨레]  자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다.',
#  '대전 대덕 출신 김창수 의원은 지난 31일 “정권 교체를 위한 야권대통합과 한반도 평화세력의 대동단결을 위해 정치적인 고향인 민주통합당에 복귀하겠다”며 자유선진당 탈당을 선언했다.',
#  '2000년 새천년민주당 창당 발기인으로 참여한 김 의원은 “당이 김정일 사망 국면에서 수구보수적인 대북정책으로 일관하는 데 실망했다”고 말했다.',
#  '문정림 선진당 대변인은 논평에서 “국회 재입성을 위해, 하루아침에 소신과 명분을 달리 표현하는 양면 모습이 안타깝기만 하다”고 비판했다.',
#  '앞서 29일엔 대전 유성출신으로 17대 땐 열린우리당 소속이던 이상민 의원이 민주통합당 입당을 선언하며 탈당했고, 지난달 1일엔 충북 보은·옥천·영동 출신인 이용희 의원이 탈당해 민주통합당에 입당했다.',
#  '2008년 4월 총선에서 18석을 얻으며 그해 8월 창조한국당과 교섭단체까지 꾸리기도 했던 선진당은 의석이 15석으로 줄면서 창당 이래 최대 위기를 맞게 됐다.',
#  '선진당은 이용희 의원의 탈당으로 충북엔 의석이 없어지면서 ‘충청권 맹주’라는 말도 무색하게 됐다.',
#  '선진당의 위기는 예견된 것이란 평이 많다.',
#  '선진당은 전국 정당화를 내걸었지만 지역주의에서 벗어나지 못했다는 평가가 적지 않다.',
#  '지난해 11월 심대평 대표와 이명박 대통령의 비밀회동 사실이 알려지며 야당으로서의 정체성에 치명상을 입기도 했다.',
#  '지난해 26~27일 실시한 <한겨레>-한국사회여론조사연구소(KSOI) 여론조사에서 선진당은 대전·충청 지역에서 4.2%의 지지를 얻어 민주통합당(31.0%)과 한나라당(26.0%)에 크게 못미쳤다.']

# %%
df_2012['last_sentence'].iloc[10]
# Out:
# '| 공식 SNS 계정 [경향 트위터] [미투데이] [페이스북] [세상과 경향의 소통 Khross]- ⓒ 경향신문 & 경향닷컴(www.khan.co.kr), 무단전재 및 재배포 금지〈경향닷컴은 한국온라인신문협회(www.kona.or.kr)의 디지털뉴스이용규칙에 따른 저작권을 행사합니다.〉'

# %%
df_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28431 entries, 0 to 28430
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      28431 non-null  object
#  1   content    28431 non-null  object
#  2   sentences  28431 non-null  object
# dtypes: object(3)
# memory usage: 666.5+ KB

# %%
df_2012['sentences'][10]
# Out:
# ['한나라당 박근혜 비상대책위원장(앞줄 왼쪽에서 네번째)과 당직자들이 1일 서울 여의도 당사에서 열린 신년 인사회에서 대형 시루떡을 자르고 있다.',
#  '| 박민규 기자 parkyu@kyunghyang.com\nㆍ예결위원장 573억원 확보여야가 올해 예산안에 지역구 예산을 1조원가량 증액시킨 것으로 나타났다.',
#  '사실상 ‘깜깜이’로 진행된 예산안 심사에서 4월 총선을 앞두고 지역구 의원들의 선심성 예산 밀어넣기가 극심했다.지역구 예산 증액은 국회 예산결산특별위원회 소속 의원들이 주도했다.',
#  '한나라당 소속 정갑윤 예결위원장(울산 중구)은 울산지역 예산을 573억원 확보했다.',
#  '울산혁신도시 지하저류조 설치(113억원), 울산신항 남방파제 2단계 사업 설계비(40억원), 도시관광활성화사업(20억원) 등 신규사업비 302억원을 포함시켰다.',
#  '계속사업도 KCC울산 봉계 일반산업단지 폐수종말 처리시설(48억원), 울산과학기술대 2012년 출연금(44억원) 등 271억원이 증액됐다.',
#  '정 위원장은 이와 별도로 2500억원 한도의 울산과학기술대 2단계 임대형 민자사업(BTL)도 예산안에 반영시켰다.예결위 계수조정소위 위원들도 가세했다.',
#  '한나라당 이종혁 의원(부산 진을)은 부산지역 예산 1767억원을 집어넣었다.',
#  '부산외곽순환고속도로(400억원), 남해고속도로 확장(400억원) 등 사회간접자본(SOC) 사업 비중이 높다.',
#  '항노화산업지원센터 신설(40억원), 중기청 지식산업센터 유치(79억원) 등 신규사업도 추가됐다.광주·전남 예산은 계수조정소위 위원인 한나라당 이정현 의원(비례대표)과 민주통합당 강기정 간사 등이 주도해 1000억원 이상을 증액시켰다.',
# ...

# %%
df_2012['sentences'].iloc[28430][:-1]
# Out:
# ["'거대 야당 견제론' vs '정권 심판론'[CBS 임진수 기자] 4.11 총선이 하루 앞으로 다가온 가운데 여야 정치권은 이번 총선 승부의 최대 분수령이 될 수도권 지역에서 치열한 막판 유세전을 이어가고 있다.전날 서울 서부지역 유세에 집중했던 새누리당 박근혜 선대위원장은 10일에는 서울 동작구와 구로구, 서대문구, 도봉, 노원, 그리고 경기도 의정부와 구리, 용인, 수원 등을 찾는다.",
#  '동서남북을 가리지 않고 수도권에서 여야가 박빙의 승부를 펼치고 있는 격전지를 방문하는 일정이다.박 위원장은 이날도 거대 야당 견제론을 강조하며 보수층을 결집하고 부동층의 견제심리를 자극하고 나설 계획이다.',
#  '박 위원장은 전날 유세에서도 "앞으로 국회에서 두 당 연대가 다수당이 될 가능성이 현재까지는 매우 높다"며 "두 거대 야당이 다수당이 돼 연일 이념투쟁과 정치투쟁하는 최악의 국회는 막아야 되지 않겠는가"라고 강조했다.',
#  '그는 "야당의 한 후보가 여성과 노인, 특정 종교에 대해 차마 입에 담을수 없는 막말을 한게 문제가 되고 있다"며 \'김용민 심판론\'도 주요한 카드로 사용하고 있다.',
#  '민주통합당 한명숙 대표는 전날 새벽 서울 가락시장을 찾는 것을 시작으로 수도권에서 48시간 릴레이 유세에 들어갔다.',
#  '이날은 2,30대 젊은 세대의 투표 참여를 이끌어내기 위해 연세대, 이화여대, 서강대 등 신촌 일대를 비롯해 건국대, 경희대 등 서울지역 대학가를 순회 방문할 계획이다.',
#  "한 대표는 이날도 수도권 선거의 승패가 투표율에 달렸다고 보고 청년층 투표 독려에 혼신을 다한다는 계획이다.민주당은 전날 신촌 연세대 정문앞에서 청년층에게 신망이 두터운 작가 공지영 씨와 서울대 조국 교수를 초청해 '청년 투표참여 캠페인'을 열기도 했다.",
# ...

# %%
import re

sentences_list = df_2012['sentences']

# split_sentences 열을 추가하고 각 행마다 새로운 빈 리스트로 초기화
df_2012['split_sentences'] = [[] for _ in range(len(df_2012))]

# 리스트의 각 요소에 대해 문장 분리 수행
for i, sentences in enumerate(sentences_list):
    split_sentences = []
    for sentence in sentences:
        split_sentences.extend(re.split(r'(?<=[.!?])\s+', sentence))
    df_2012.at[i, 'split_sentences'] = split_sentences

df_2012['split_sentences']
# Out:
# 0        [[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 ...
# 1        [[한겨레]  자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다., 대전 대덕 ...
# 2        [ㆍ세수 증가 효과는 제한적… 정부 감세정책 ‘벼랑 끝’과세표준 3억원 초과 구간에...
# 3        [ㆍ여당 요구 대폭 수용 ‘반쪽’종합편성채널(종편)의 직접 광고 영업을 막는 ‘방송...
# 4        [ㆍ4년간 한번도 합의처리 못해2012년 예산안이 사실상 한나라당 단독 처리로 국회...
#                                ...
# 28426    [소설가 이외수씨(66)가 새누리당 한기호 후보를 지지하고 나섰다., 9일 새벽 이...
# 28427    [새누리당 이혜훈 종합상황실장이 10일 "투표율이 올라가면 새누리당이 유리하다"고 ...
# 28428    [연기군 부군수에게 공무원 중립 요청한 말이 “폭언”으로…새누리 “혹세무민”·선진 ...
# 28429    [4·11 총선을 하루 앞두고 새누리당 박근혜 중앙선거대책위원장과 민주통합당 한명숙...
# 28430    ['거대 야당 견제론' vs '정권 심판론'[CBS 임진수 기자] 4.11 총선이 ...
# Name: split_sentences, Length: 28431, dtype: object

# %%
df_2012['sentences'][2]
# Out:
# ['ㆍ세수 증가 효과는 제한적… 정부 감세정책 ‘벼랑 끝’과세표준 3억원 초과 구간에 38% 세율을 적용하는 ‘한국판 버핏세(부자증세)’ 법안이 지난달 31일 국회 본회의를 통과했다.',
#  '한나라당 쇄신파 의원 일부가 탈당을 내세워 지도부에 법 처리를 압박한 것으로 전해졌다.',
#  '첫 부자증세라는 상징성은 있으나, 세수증가 효과는 제한적이라 ‘무늬만 버핏세’라는 지적이 나온다.당초 국회 본회의에 올라간 소득세법 개정안은 정부가 제출한 것이다.',
#  '월 소득공제를 1인가구까지 확대하는 내용 등을 골자로 하고 있다.',
#  '이 법이 통과되면 ‘과세표준 8800만원 초과 소득에 35%의 세율을 적용’하는 현행 제도가 그대로 간다.한나라당 조문환, 민주통합당 이용섭 의원 등 여야 의원 52명은 지난달 30일 ‘2억원 초과’ 최고구간 신설과 38% 최고세율 적용을 골자로 한 법 개정안을 본회의에 수정안으로 내놨다.',
#  '이 경우 2009년 기준으로 전체 소득자의 0.35%인 6만3000명이 해당돼 7700억원가량의 세수를 추가 확보할 수 있을 것으로 전망됐다.하지만 한나라당 지도부가 제동을 걸었다.',
#  '지난달 31일 본회의를 앞두고 한나라당이 의총을 열고 토론을 통해 2억원 기준 대신 3억원으로 바꾼 수정안을 냈다.야당은 반발했다.',
#  '이용섭 의원(61)은 본회의 반대토론에서 “3억원으로 과표구간을 올리는 것은 무늬와 모양만 부자증세이지, 실제 취지에 맞지 않고 실효성이 없다”고 말했다.',
#  '3억원 초과 소득자는 전체 소득자의 0.17%로 연간 추가 세수도 5000억원에 불과하다고 주장했다.',
#  '한나라당 내에서도 “실제 세수보다는 그 상징성을 봐달라”(한 재선 의원)는 얘기가 나왔다.야당 의원들의 반대토론 신청이 줄잇자 박희태 국회의장(74)은 ‘토론종결 동의건’을 받아들여 표결을 실시했다.',
# ...

# %%
df_2012['split_sentences'][2]
# Out:
# ['ㆍ세수 증가 효과는 제한적… 정부 감세정책 ‘벼랑 끝’과세표준 3억원 초과 구간에 38% 세율을 적용하는 ‘한국판 버핏세(부자증세)’ 법안이 지난달 31일 국회 본회의를 통과했다.',
#  '한나라당 쇄신파 의원 일부가 탈당을 내세워 지도부에 법 처리를 압박한 것으로 전해졌다.',
#  '첫 부자증세라는 상징성은 있으나, 세수증가 효과는 제한적이라 ‘무늬만 버핏세’라는 지적이 나온다.당초 국회 본회의에 올라간 소득세법 개정안은 정부가 제출한 것이다.',
#  '월 소득공제를 1인가구까지 확대하는 내용 등을 골자로 하고 있다.',
#  '이 법이 통과되면 ‘과세표준 8800만원 초과 소득에 35%의 세율을 적용’하는 현행 제도가 그대로 간다.한나라당 조문환, 민주통합당 이용섭 의원 등 여야 의원 52명은 지난달 30일 ‘2억원 초과’ 최고구간 신설과 38% 최고세율 적용을 골자로 한 법 개정안을 본회의에 수정안으로 내놨다.',
#  '이 경우 2009년 기준으로 전체 소득자의 0.35%인 6만3000명이 해당돼 7700억원가량의 세수를 추가 확보할 수 있을 것으로 전망됐다.하지만 한나라당 지도부가 제동을 걸었다.',
#  '지난달 31일 본회의를 앞두고 한나라당이 의총을 열고 토론을 통해 2억원 기준 대신 3억원으로 바꾼 수정안을 냈다.야당은 반발했다.',
#  '이용섭 의원(61)은 본회의 반대토론에서 “3억원으로 과표구간을 올리는 것은 무늬와 모양만 부자증세이지, 실제 취지에 맞지 않고 실효성이 없다”고 말했다.',
#  '3억원 초과 소득자는 전체 소득자의 0.17%로 연간 추가 세수도 5000억원에 불과하다고 주장했다.',
#  '한나라당 내에서도 “실제 세수보다는 그 상징성을 봐달라”(한 재선 의원)는 얘기가 나왔다.야당 의원들의 반대토론 신청이 줄잇자 박희태 국회의장(74)은 ‘토론종결 동의건’을 받아들여 표결을 실시했다.',
# ...

# %% [markdown]
# ## 문장 토큰화 후 한 줄씩 컬럼에 저장

# %%
## content 데이터를 문장토큰화 후 한줄씩 컬럼을 생성해서 데이터 프레임으로 저장
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

test = df_2012[:5]

# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
test['sentences'] = test['content'].apply(tokenize_sentences)

# sentences 열에서 각 행의 리스트를 추출하여 데이터프레임의 새로운 열로 추가
for index, row in test.iterrows():
    sentences = row['sentences']
    for i, sentence in enumerate(sentences):
        test.loc[index, f'sentence_{i+1}'] = sentence

# 결과 확인
test
# Out:
# C:\Users\mit06\AppData\Local\Temp\ipykernel_8404\2419688195.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['sentences'] = test['content'].apply(tokenize_sentences)
# C:\Users\mit06\AppData\Local\Temp\ipykernel_8404\2419688195.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.loc[index, f'sentence_{i+1}'] = sentence
# C:\Users\mit06\AppData\Local\Temp\ipykernel_8404\2419688195.py:22: SettingWithCopyWarning:
# ...

# %%
## content 데이터를 문장토큰화 후 한줄씩 컬럼을 생성해서 데이터 프레임으로 저장(최종)
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
df_2012['sentences'] = df_2012['content'].apply(tokenize_sentences)

# sentences 열에서 각 행의 리스트를 추출하여 데이터프레임의 새로운 열로 추가
for index, row in df_2012.iterrows():
    sentences = row['sentences']
    for i, sentence in enumerate(sentences):
        df_2012.loc[index, f'sentence_{i+1}'] = sentence

# 결과 확인
df_2012
# Out:
# C:\Users\mit06\AppData\Local\Temp\ipykernel_8404\93870882.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2012.loc[index, f'sentence_{i+1}'] = sentence
# C:\Users\mit06\AppData\Local\Temp\ipykernel_8404\93870882.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_2012.loc[index, f'sentence_{i+1}'] = sentence
# ...

# %%
import numpy as np
row_index = np.arabge(0, 354)
is_not_nan = df_2012.iloc[row_index].notna()
any_not_nan = is_not_nan.all()
any_not_nan
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[116], line 2
#       1 import numpy as np
# ----> 2 row_index = np.arabge(0, 354)
#       3 is_not_nan = df_2012.iloc[row_index].notna()
#       4 any_not_nan = is_not_nan.all()
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arabge'

# %% [markdown]
# ## 필요 없는 문장 날리기

# %%
df_2012 = pd.read_csv('2012_news.csv')

# %%
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
df_2012['sentences'] = df_2012['content'].apply(tokenize_sentences)
df_2012['sentences'] = df_2012['sentences'].apply(lambda x: x[:-1] if x else [])
df_2012 = df_2012.drop('content', axis=1)


# 결과 확인
df_2012
# Out:
#                                               title  \
# 0                                  ‘버핏세 반란’에 밀린 박근혜
# 1                                김창수 의원도 탈당…위기의 선진당
# 2                                첫 부자증세지만 ‘무늬만 버핏세’
# 3                           여야 ‘방송광고판매대행법’ 5일 처리 예정
# 4                          사실상 ‘박근혜 예산’ 한나라당, 단독 처리
# ...                                             ...
# 28426                        이외수 “새누리 후보 지지” 트위터 발칵
# 28427               이혜훈 "투표율 올라가면 보수층 몰려 새누리당 유리하다"
# 28428                      세종시 총선, ‘이해찬 막말 파문’의 결과는
# 28429  [총선 D-1]박근혜, 한명숙의 선택은? '수도권 릴레이' vs '대학가 공략'
# 28430                         총선 D-1, 여야 수도권 공략 총력전
#
#                                                sentences
# 0      [[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 ...
# 1      [[한겨레]  자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다., 대전 대덕 ...
# 2      [ㆍ세수 증가 효과는 제한적… 정부 감세정책 ‘벼랑 끝’과세표준 3억원 초과 구간에...
# 3      [ㆍ여당 요구 대폭 수용 ‘반쪽’종합편성채널(종편)의 직접 광고 영업을 막는 ‘방송...
# ...

# %%
df_2012['sentences'][202]
# Out:
# ['[ 뉴스1 제공 ](서울=뉴스1) 박정호 기자 = \n\n\n\n2012년도 새해예산안이 국회를 통과한 후 차수변경으로 1일 새해를 맞은 서울 여의도 국회 본회의장에서 한나라당 이상득 전 국회부의장과 황우여 원내대표가 상반된 표정을 보이고 있다.',
#  '<저작권자 뉴스1 코리아, 무단전재 및 재배포 금지>\n\n☞ 뉴스1 바로가기 \n\n[나도 부자가 될 수 있을까?',
#  '긴급 추천 스마트정보!]',
#  '[내손안의 스마트한 경제정보 머니투데이 모바일]\n\n\n[머니투데이 핫뉴스]☞ [흑룡의 해]2012년 대한민국과 안철수,박근혜 운세는\n☞ "왜 한국엔 명품 속옷이 없죠?"',
#  '☞ 전문가 선택 "상반기가 내집마련 적기"\n☞ 안철수vs박근혜 지지율 양자대결은 安-다자는 朴\n☞ \'왕따 자살의 원인은 부모에게?\'']

# %%
df_2012_test['content'][202]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df_2012_test['content'][202]
#
# NameError: name 'df_2012_test' is not defined

# %%
df_2012['sentences'].iloc[202]
# Out:
# ['[ 뉴스1 제공 ](서울=뉴스1) 박정호 기자 = \n\n\n\n2012년도 새해예산안이 국회를 통과한 후 차수변경으로 1일 새해를 맞은 서울 여의도 국회 본회의장에서 한나라당 이상득 전 국회부의장과 황우여 원내대표가 상반된 표정을 보이고 있다.',
#  '<저작권자 뉴스1 코리아, 무단전재 및 재배포 금지>\n\n☞ 뉴스1 바로가기 \n\n[나도 부자가 될 수 있을까?',
#  '긴급 추천 스마트정보!]',
#  '[내손안의 스마트한 경제정보 머니투데이 모바일]\n\n\n[머니투데이 핫뉴스]☞ [흑룡의 해]2012년 대한민국과 안철수,박근혜 운세는\n☞ "왜 한국엔 명품 속옷이 없죠?"',
#  '☞ 전문가 선택 "상반기가 내집마련 적기"\n☞ 안철수vs박근혜 지지율 양자대결은 安-다자는 朴\n☞ \'왕따 자살의 원인은 부모에게?\'']

# %%
## 뉴스 뒷부분에 필요없는 부분 제거
from tqdm import tqdm

# 새로운 열을 생성하기 위해 빈 리스트 초기화
new_content = []

for i in tqdm(range(len(df_2012))):
    res = []
    for j in range(len(df_2012['sentences'].iloc[i])):
        if not re.search(r'<.*?>', df_2012['sentences'].iloc[i][j]) or not ('@' in df_2012['sentences'].iloc[i][j]):
            res.append(df_2012['sentences'].iloc[i][j])
        else:
            break
    # 각 행에 대한 결과를 빈 리스트에 추가
    new_content.append(res)

# 새로운 열로 할당
df_2012['new_content'] = new_content
# Out:
# 100%|██████████████████████████████████| 28431/28431 [00:01<00:00, 21356.36it/s]

# %%
df_2012['new_content'][10]
# Out:
# ['한나라당 박근혜 비상대책위원장(앞줄 왼쪽에서 네번째)과 당직자들이 1일 서울 여의도 당사에서 열린 신년 인사회에서 대형 시루떡을 자르고 있다.',
#  '| 박민규 기자 parkyu@kyunghyang.com\nㆍ예결위원장 573억원 확보여야가 올해 예산안에 지역구 예산을 1조원가량 증액시킨 것으로 나타났다.',
#  '사실상 ‘깜깜이’로 진행된 예산안 심사에서 4월 총선을 앞두고 지역구 의원들의 선심성 예산 밀어넣기가 극심했다.지역구 예산 증액은 국회 예산결산특별위원회 소속 의원들이 주도했다.',
#  '한나라당 소속 정갑윤 예결위원장(울산 중구)은 울산지역 예산을 573억원 확보했다.',
#  '울산혁신도시 지하저류조 설치(113억원), 울산신항 남방파제 2단계 사업 설계비(40억원), 도시관광활성화사업(20억원) 등 신규사업비 302억원을 포함시켰다.',
#  '계속사업도 KCC울산 봉계 일반산업단지 폐수종말 처리시설(48억원), 울산과학기술대 2012년 출연금(44억원) 등 271억원이 증액됐다.',
#  '정 위원장은 이와 별도로 2500억원 한도의 울산과학기술대 2단계 임대형 민자사업(BTL)도 예산안에 반영시켰다.예결위 계수조정소위 위원들도 가세했다.',
#  '한나라당 이종혁 의원(부산 진을)은 부산지역 예산 1767억원을 집어넣었다.',
#  '부산외곽순환고속도로(400억원), 남해고속도로 확장(400억원) 등 사회간접자본(SOC) 사업 비중이 높다.',
#  '항노화산업지원센터 신설(40억원), 중기청 지식산업센터 유치(79억원) 등 신규사업도 추가됐다.광주·전남 예산은 계수조정소위 위원인 한나라당 이정현 의원(비례대표)과 민주통합당 강기정 간사 등이 주도해 1000억원 이상을 증액시켰다.',
# ...

# %%
df_2012_test['content'][9]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df_2012_test['content'][9]
#
# NameError: name 'df_2012_test' is not defined

# %%
from tqdm import tqdm

# 새로운 열을 생성하기 위해 빈 리스트 초기화
new_sentences = []

for i in tqdm(range(len(df_2012))):
    res = []
    for j in range(len(df_2012['sentences'].iloc[i])):
        if re.search(r'<.*?>', df_2012['sentences'].iloc[i][j]) or ('@' in df_2012['sentences'].iloc[i][j]):
            break
        else:
            res.append(df_2012['sentences'].iloc[i][j])
    # 각 행에 대한 결과를 빈 리스트에 추가
    new_sentences.append(res)

# 새로운 열로 할당
df_2012['new_sentences'] = new_sentences
# Out:
# 100%|██████████████████████████████████| 28431/28431 [00:01<00:00, 17938.59it/s]

# %%
df_2012['new_sentences'][10001]
# Out:
# ['(서울=연합뉴스) 서명곤 기자 = 새누리당 김종인 비대위원이 8일 오전 국회 새누리당 정책위의장실에서 열린 비대위 정책쇄신분과회의에서 모두발언을 하고 있다.',
#  '김종인 비대위원은 회의에서 "정책쇄신분과위를 오늘까지만 운영하고 당분간 회의를 하지 않으려 한다"고 밝혔다.']

# %%
df_2012['new_sentences'][9]
# Out:
# ['민주통합당 당 대표에 도전한 박지원 후보(70)는 “나는 민주당의 뿌리이고 뼛속까지 민주당”이라며 “이명박 정권과 한나라당이 제일 두려워하는 사람이 민주통합당에 필요하다”고 말했다.',
#  '그는 1일 경향신문과의 인터뷰에서 “다른 후보들과 달리 지난 4년 동안 이명박 정권에 투쟁해왔다”며 “ ‘김대중·호남’ 세력을 대표하는 사람으로서 이들을 껴안아 총선 승리와 정권교체를 이룰 수 있는 유일한 인물”이라고 말했다.- 박지원이 당 대표가 돼야 하는 이유는.“이명박 정부 4년간 의정활동이나 원내대표로서 국민 속에 민주당의 존재감을 확인시켰다.',
#  '이명박 정권과 한나라당에 맞서 투쟁한, 그리고 1998년 정권교체를 이뤘던 경험 등을 가진 유일한 사람이다.',
#  '이번에는 총선에서 승리를 거둘 당 대표가 필요하다.',
#  '박지원만이 갖추고 있다고 본다.”- 전통 지지층인 호남세력을 안고 가야 대선에서 승리할 수 있다는 논리가 새로운 정치를 요구하는 목소리와 배치된다는 지적도 나온다.“진짜 잘못된 지적이라고 생각한다.',
#  '선거는 이기기 위해 하는 것이다.',
#  '학자나 시민사회는 말과 사상으로 세상을 바꾸려 하지만 정치는 승리해서 세상을 바꾼다.',
#  '왜 당 지지층을 한나라당과 같은 논리로 의도적으로 배제하는가.',
#  '호남세력도 함께 안고 가자는 거다.',
#  '그래야 정권교체도 할 수 있다.”- 민주통합당으로의 통합을 평가한다면.“결과적으로 진보개혁 세력이 다 함께하지는 못했지만, 결국 민주당과 시민사회, 노동계가 함께한 것은 굉장히 의미 있다고 생각한다.',
#  '이제는 ‘샐러드 볼(salad bowl)’처럼 자기 맛도 유지하면서 전체적으로 조화로운 맛을 내야 한다.',
#  '서로를 인정하고 조화를 이뤄나가는 데 어떤 세력의 집중이 아니라 균형을 갖출 때 진정한 승리를 갖출 수 있다고 본다.”- 민주통합당의 향후 과제는 어떤 것이 돼야 하나.“민주통합당의 강령은 평화, 복지, 그리고 재벌개혁이다.',
# ...

# %%
df_2012_test = pd.read_csv('2012_news.csv')

# %%
df_2012_test['content'][202]
# Out:
# '[ 뉴스1 제공 ](서울=뉴스1) 박정호 기자 = \n\n\n\n2012년도 새해예산안이 국회를 통과한 후 차수변경으로 1일 새해를 맞은 서울 여의도 국회 본회의장에서 한나라당 이상득 전 국회부의장과 황우여 원내대표가 상반된 표정을 보이고 있다.\n\n<저작권자 뉴스1 코리아, 무단전재 및 재배포 금지>\n\n☞ 뉴스1 바로가기 \n\n[나도 부자가 될 수 있을까? 긴급 추천 스마트정보!]\n[내손안의 스마트한 경제정보 머니투데이 모바일]\n\n\n[머니투데이 핫뉴스]☞ [흑룡의 해]2012년 대한민국과 안철수,박근혜 운세는\n☞ "왜 한국엔 명품 속옷이 없죠?"\n☞ 전문가 선택 "상반기가 내집마련 적기"\n☞ 안철수vs박근혜 지지율 양자대결은 安-다자는 朴\n☞ \'왕따 자살의 원인은 부모에게?\' 윤서인 웹툰 논란 \n\n\n\n\n\n\n\n\n뉴스1 제공 \n<저작권자 ⓒ \'돈이 보이는 리얼타임 뉴스\' 머니투데이, 무단전재 및 재배포 금지>'

# %%
df_2012 = pd.read_csv('2012_news.csv')

# %%
df_2012['content'][10]
# Out:
# '한나라당 박근혜 비상대책위원장(앞줄 왼쪽에서 네번째)과 당직자들이 1일 서울 여의도 당사에서 열린 신년 인사회에서 대형 시루떡을 자르고 있다. | 박민규 기자 parkyu@kyunghyang.com\nㆍ예결위원장 573억원 확보여야가 올해 예산안에 지역구 예산을 1조원가량 증액시킨 것으로 나타났다. 사실상 ‘깜깜이’로 진행된 예산안 심사에서 4월 총선을 앞두고 지역구 의원들의 선심성 예산 밀어넣기가 극심했다.지역구 예산 증액은 국회 예산결산특별위원회 소속 의원들이 주도했다. 한나라당 소속 정갑윤 예결위원장(울산 중구)은 울산지역 예산을 573억원 확보했다. 울산혁신도시 지하저류조 설치(113억원), 울산신항 남방파제 2단계 사업 설계비(40억원), 도시관광활성화사업(20억원) 등 신규사업비 302억원을 포함시켰다. 계속사업도 KCC울산 봉계 일반산업단지 폐수종말 처리시설(48억원), 울산과학기술대 2012년 출연금(44억원) 등 271억원이 증액됐다.  정 위원장은 이와 별도로 2500억원 한도의 울산과학기술대 2단계 임대형 민자사업(BTL)도 예산안에 반영시켰다.예결위 계수조정소위 위원들도 가세했다. 한나라당 이종혁 의원(부산 진을)은 부산지역 예산 1767억원을 집어넣었다. 부산외곽순환고속도로(400억원), 남해고속도로 확장(400억원) 등 사회간접자본(SOC) 사업 비중이 높다. 항노화산업지원센터 신설(40억원), 중기청 지식산업센터 유치(79억원) 등 신규사업도 추가됐다.광주·전남 예산은 계수조정소위 위원인 한나라당 이정현 의원(비례대표)과 민주통합당 강기정 간사 등이 주도해 1000억원 이상을 증액시켰다. 영암호 통선문(300억원), 광주 총인처리시설 설치(117억원), F1 대회 운영비(50억원) 등이 신규 사업으로 포함됐다.서울지역 의원으로 계수조정소위에 참여한 한나라당 구상찬 의원(강서갑)도 복합문화복지센터(10억원), 수해예방사업(35억원), LCD 보안등 설치(10억원) 등 60억원 규모의 지역구 예산을 확보했다.국회 예결위 관계자는 “
# ...

# %% [markdown]
# ## 단어 토큰화

# %%
df_2012
# Out:
#                                               title  \
# 0                                  ‘버핏세 반란’에 밀린 박근혜
# 1                                김창수 의원도 탈당…위기의 선진당
# 2                                첫 부자증세지만 ‘무늬만 버핏세’
# 3                           여야 ‘방송광고판매대행법’ 5일 처리 예정
# 4                          사실상 ‘박근혜 예산’ 한나라당, 단독 처리
# ...                                             ...
# 28426                        이외수 “새누리 후보 지지” 트위터 발칵
# 28427               이혜훈 "투표율 올라가면 보수층 몰려 새누리당 유리하다"
# 28428                      세종시 총선, ‘이해찬 막말 파문’의 결과는
# 28429  [총선 D-1]박근혜, 한명숙의 선택은? '수도권 릴레이' vs '대학가 공략'
# 28430                         총선 D-1, 여야 수도권 공략 총력전
#
#                                                sentences  \
# 0      [[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 ...
# 1      [[한겨레]  자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다., 대전 대덕 ...
# 2      [ㆍ세수 증가 효과는 제한적… 정부 감세정책 ‘벼랑 끝’과세표준 3억원 초과 구간에...
# 3      [ㆍ여당 요구 대폭 수용 ‘반쪽’종합편성채널(종편)의 직접 광고 영업을 막는 ‘방송...
# ...

# %% [markdown]
# ## 최종 문장 토큰화

# %%
import pandas as pd
df_2012 = pd.read_csv('2012_news.csv')

# %%
## 역슬래시가 포함된 단어 변경
import re

def replace_backslash_with_space(text):
    # 정규표현식을 사용하여 역슬래시를 공백으로 대체
    clean_text = re.sub(r'[\\n\s]+', ' ', text)
    return clean_text

# 역슬래시를 공백으로 변경한 결과를 새로운 열에 저장
df_2012['content'] = df_2012['content'].apply(replace_backslash_with_space)

# %%
## 문장 토큰화
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
df_2012['sentences'] = df_2012['content'].apply(tokenize_sentences)
df_2012['sentences'] = df_2012['sentences'].apply(lambda x: x[:-1] if x else [])
df_2012 = df_2012.drop('content', axis=1)

# %%
## 필요 없는 부분 제거 (기자 이메일, 광고 ..)
from tqdm import tqdm

# 새로운 열을 생성하기 위해 빈 리스트 초기화
new_sentences = []

for i in tqdm(range(len(df_2012))):
    res = []
    for j in range(len(df_2012['sentences'].iloc[i])):
        if re.search(r'<.*?>', df_2012['sentences'].iloc[i][j]) or ('@' in df_2012['sentences'].iloc[i][j]) or ('☞'  in df_2012['sentences'].iloc[i][j]):
            break
        else:
            res.append(df_2012['sentences'].iloc[i][j])
    # 각 행에 대한 결과를 빈 리스트에 추가
    new_sentences.append(res)

# 새로운 열로 할당
df_2012['new_sentences'] = new_sentences
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 28431/28431 [00:05<00:00, 5153.00it/s]

# %%
# new_sentences 열에 있는 각 문장들을 하나의 문서로 합침
merged_documents = []

for sentences in df_2012['new_sentences']:
    merged_document = ' '.join(sentences)
    merged_documents.append(merged_document)

# 컬럼 추가
df_2012['new_content'] = merged_documents

# %%
## 결과 확인
df_2012[['title', 'new_sentences']]
# Out:
#                                               title  \
# 0                                  ‘버핏세 반란’에 밀린 박근혜
# 1                                김창수 의원도 탈당…위기의 선진당
# 2                                첫 부자증세지만 ‘무늬만 버핏세’
# 3                           여야 ‘방송광고판매대행법’ 5일 처리 예정
# 4                          사실상 ‘박근혜 예산’ 한나라당, 단독 처리
# ...                                             ...
# 28426                        이외수 “새누리 후보 지지” 트위터 발칵
# 28427               이혜훈 "투표율 올라가면 보수층 몰려 새누리당 유리하다"
# 28428                      세종시 총선, ‘이해찬 막말 파문’의 결과는
# 28429  [총선 D-1]박근혜, 한명숙의 선택은? '수도권 릴레이' vs '대학가 공략'
# 28430                         총선 D-1, 여야 수도권 공략 총력전
#
#                                            new_sentences
# 0      [[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 ...
# 1      [[한겨레] 자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다., 대전 대덕 출...
# 2      [ㆍ세수 증가 효과는 제한적… 정부 감세정책 ‘벼랑 끝’과세표준 3억원 초과 구간에...
# 3      [ㆍ여당 요구 대폭 수용 ‘반쪽’종합편성채널(종편)의 직접 광고 영업을 막는 ‘방송...
# ...

# %%
df_2012
# Out:
#                                               title  \
# 0                                  ‘버핏세 반란’에 밀린 박근혜
# 1                                김창수 의원도 탈당…위기의 선진당
# 2                                첫 부자증세지만 ‘무늬만 버핏세’
# 3                           여야 ‘방송광고판매대행법’ 5일 처리 예정
# 4                          사실상 ‘박근혜 예산’ 한나라당, 단독 처리
# ...                                             ...
# 28426                        이외수 “새누리 후보 지지” 트위터 발칵
# 28427               이혜훈 "투표율 올라가면 보수층 몰려 새누리당 유리하다"
# 28428                      세종시 총선, ‘이해찬 막말 파문’의 결과는
# 28429  [총선 D-1]박근혜, 한명숙의 선택은? '수도권 릴레이' vs '대학가 공략'
# 28430                         총선 D-1, 여야 수도권 공략 총력전
#
#                                                sentences  \
# 0      [[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 ...
# 1      [[한겨레] 자유선진당이 소속 의원들의 잇따른 탈당으로 뒤숭숭하다., 대전 대덕 출...
# 2      [ㆍ세수 증가 효과는 제한적… 정부 감세정책 ‘벼랑 끝’과세표준 3억원 초과 구간에...
# 3      [ㆍ여당 요구 대폭 수용 ‘반쪽’종합편성채널(종편)의 직접 광고 영업을 막는 ‘방송...
# ...

# %% [markdown]
# ## 단어 토큰화

# %% [markdown]
# ### Komoran

# %%
import pandas as pd
df_2012 = pd.read_csv('2012_news.csv')

## 역슬래시가 포함된 단어 변경
import re

def replace_backslash_with_space(text):
    # 정규표현식을 사용하여 역슬래시를 공백으로 대체
    clean_text = re.sub(r'[\\n\s]+', ' ', text)
    return clean_text

# 역슬래시를 공백으로 변경한 결과를 새로운 열에 저장
df_2012['content'] = df_2012['content'].apply(replace_backslash_with_space)

## 문장 토큰화
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
df_2012['sentences'] = df_2012['content'].apply(tokenize_sentences)
df_2012['sentences'] = df_2012['sentences'].apply(lambda x: x[:-1] if x else [])
df_2012 = df_2012.drop('content', axis=1)

## 필요 없는 부분 제거 (기자 이메일, 광고 ..)
from tqdm import tqdm

# 새로운 열을 생성하기 위해 빈 리스트 초기화
new_sentences = []

for i in tqdm(range(len(df_2012))):
    res = []
    for j in range(len(df_2012['sentences'].iloc[i])):
        if re.search(r'<.*?>', df_2012['sentences'].iloc[i][j]) or ('@' in df_2012['sentences'].iloc[i][j]):
            break
        else:
            res.append(df_2012['sentences'].iloc[i][j])
    # 각 행에 대한 결과를 빈 리스트에 추가
    new_sentences.append(res)

# 새로운 열로 할당
df_2012['new_sentences'] = new_sentences

# new_sentences 열에 있는 각 문장들을 하나의 문서로 합침
merged_documents = []

for sentences in df_2012['new_sentences']:
    merged_document = ' '.join(sentences)
    merged_documents.append(merged_document)

# 컬럼 추가
df_2012['new_content'] = merged_documents
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 28431/28431 [00:04<00:00, 5955.46it/s]

# %%
#pip install konlpy

# %%
## 문서 전체
from konlpy.tag import Komoran
from tqdm import tqdm

# Komoran 객체 생성
komoran = Komoran()

# 데이터프레임의 각 행에 대해 형태소 분석을 수행하고 결과를 리스트에 저장
results = []
texts = df_2012['new_content']

for text in tqdm(texts):
    try:
        result = komoran.morphs(text)
        results.append(result)
    except Exception as e:
        print(f"Error occurred for text: {text}")
        print(f"Error message: {e}")
        continue

# 결과를 데이터프레임에 추가
df_2012['morphs_Komoran'] = results
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 28431/28431 [04:00<00:00, 118.07it/s]

# %%
df_2012['morphs_Komoran'][0]
# Out:
# ['[',
#  '한겨레',
#  ']',
#  '소득세',
#  '최고',
#  '구간',
#  '반대',
#  '거스르',
#  '어',
#  '하',
#  'ㄴ',
#  '나라',
#  '당',
#  '의원',
#  '들',
#  '본회의',
#  '표결',
#  '박근혜',
#  '‘',
#  '변화',
#  '되',
#  'ㄴ',
#  '위상',
#  '’',
#  '드러나',
#  '아',
#  '한나라당',
#  '안',
#  '에서',
#  '‘',
#  '박근혜',
#  '의',
#  '뜻',
#  '’',
#  '에',
#  '브레이크',
#  '가',
#  '걸리',
#  '었',
#  '다',
#  '.',
#  '박근혜',
#  '비상대책위',
#  '원장',
#  '이',
#  '부정',
#  '적',
#  '이',
#  'ㄴ',
#  '뜻',
#  '을',
#  '나타내',
#  'ㄴ',
#  '소득세',
#  '최고',
#  '구간',
#  '신설',
#  '안',
#  '(',
#  '일명',
#  '버핏세)이',
#  '결국',
#  '여야',
#  '합의',
#  '로',
#  '지난달',
#  '31',
#  '일',
#  '국회',
#  '본회의',
#  '에서',
#  '처리',
#  '되',
#  '었',
#  '기',
#  '때문',
#  '이',
#  '다',
#  '.',
#  '서울',
#  '의',
#  '한',
#  '의원',
#  '은',
#  '“',
#  '부자',
#  '증세',
#  '도',
#  '의미',
#  '가',
#  '있',
#  '지만',
#  '한나라당',
#  '에서',
#  '박근혜',
#  '위원장',
#  '뜻대로',
#  '안',
#  '되',
#  '는',
#  '일',
#  '이',
#  '있',
#  '다는',
#  '걸',
#  'ㄹ',
#  '알리',
#  '어',
#  '주',
#  'ㄴ',
#  '의미',
#  '가',
#  '더',
#  '크',
# ...

# %% [markdown]
# ### Okt

# %%
import pandas as pd
df_2012 = pd.read_csv('2012_news.csv')

## 역슬래시가 포함된 단어 변경
import re

def replace_backslash_with_space(text):
    # 정규표현식을 사용하여 역슬래시를 공백으로 대체
    clean_text = re.sub(r'[\\n\s]+', ' ', text)
    return clean_text

# 역슬래시를 공백으로 변경한 결과를 새로운 열에 저장
df_2012['content'] = df_2012['content'].apply(replace_backslash_with_space)

## 문장 토큰화
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
df_2012['sentences'] = df_2012['content'].apply(tokenize_sentences)
df_2012['sentences'] = df_2012['sentences'].apply(lambda x: x[:-1] if x else [])
df_2012 = df_2012.drop('content', axis=1)

## 필요 없는 부분 제거 (기자 이메일, 광고 ..)
from tqdm import tqdm

# 새로운 열을 생성하기 위해 빈 리스트 초기화
new_sentences = []

for i in tqdm(range(len(df_2012))):
    res = []
    for j in range(len(df_2012['sentences'].iloc[i])):
        if re.search(r'<.*?>', df_2012['sentences'].iloc[i][j]) or ('@' in df_2012['sentences'].iloc[i][j]):
            break
        else:
            res.append(df_2012['sentences'].iloc[i][j])
    # 각 행에 대한 결과를 빈 리스트에 추가
    new_sentences.append(res)

# 새로운 열로 할당
df_2012['new_sentences'] = new_sentences

# new_sentences 열에 있는 각 문장들을 하나의 문서로 합침
merged_documents = []

for sentences in df_2012['new_sentences']:
    merged_document = ' '.join(sentences)
    merged_documents.append(merged_document)

# 컬럼 추가
df_2012['new_content'] = merged_documents
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 28431/28431 [00:04<00:00, 5913.09it/s]

# %%
## 굿
from konlpy.tag import Okt

# Okt 객체 생성
okt = Okt()

# 데이터프레임의 각 행에 대해 형태소 분석을 수행하고 결과를 리스트에 저장
results = []
texts = df_2012['new_content']

for text in tqdm(texts):
    try:
        result = okt.morphs(text)
        results.append(result)
    except Exception as e:
        print(f"Error occurred for text: {text}")
        print(f"Error message: {e}")
        continue

# 결과를 데이터프레임에 추가
df_2012['morphs_Komoran'] = results
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 28431/28431 [09:06<00:00, 52.05it/s]

# %%
df_2012['morphs_Komoran'][0]
# Out:
# ['[',
#  '한겨레',
#  ']',
#  '소득세',
#  '최고',
#  '구간',
#  '반대',
#  '거',
#  '슬러',
#  '한나라당',
#  '의원',
#  '들',
#  '본회의',
#  '표결',
#  '박근혜',
#  '‘',
#  '변화',
#  '된',
#  '위상',
#  '’',
#  '드러나',
#  '한나라당',
#  '안',
#  '에서',
#  '‘',
#  '박근혜',
#  '의',
#  '뜻',
#  '’',
#  '에',
#  '브레이크',
#  '가',
#  '걸렸다',
#  '.',
#  '박근혜',
#  '비상',
#  '대책',
#  '위원',
#  '장이',
#  '부정',
#  '적',
#  '인',
#  '뜻',
#  '을',
#  '나타낸',
#  '소득세',
#  '최고',
#  '구간',
#  '신설',
#  '안',
#  '(',
#  '일명',
#  '버핏',
#  '세',
#  ')',
#  '이',
#  '결국',
#  '여야',
#  '합의',
#  '로',
#  '지난달',
#  '31일',
#  '국회',
#  '본회의',
#  '에서',
#  '처리',
#  '됐기',
#  '때문',
#  '이다',
#  '.',
#  '서울',
#  '의',
#  '한',
#  '의원',
#  '은',
#  '“',
#  '부자',
#  '증세',
#  '도',
#  '의미',
#  '가',
#  '있지만',
#  '한나라당',
#  '에서',
#  '박근혜',
#  '위원장',
#  '뜻대로',
#  '안',
#  '되는',
#  '일이',
#  '있다는',
#  '걸',
#  '알려',
#  '준',
#  '의미',
#  '가',
#  '더',
#  '크다',
#  '”',
#  '고',
#  '말',
#  '했다',
#  '.',
#  '한나라당',
#  '일부',
#  '의원',
#  '들',
#  '이',
#  '박근혜',
#  '위원장',
#  '의',
#  '뜻',
# ...

# %% [markdown]
# ### Kkma

# %%
import pandas as pd
df_2012 = pd.read_csv('2012_news.csv')

## 역슬래시가 포함된 단어 변경
import re

def replace_backslash_with_space(text):
    # 정규표현식을 사용하여 역슬래시를 공백으로 대체
    clean_text = re.sub(r'[\\n\s]+', ' ', text)
    return clean_text

# 역슬래시를 공백으로 변경한 결과를 새로운 열에 저장
df_2012['content'] = df_2012['content'].apply(replace_backslash_with_space)

## 문장 토큰화
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
df_2012['sentences'] = df_2012['content'].apply(tokenize_sentences)
df_2012['sentences'] = df_2012['sentences'].apply(lambda x: x[:-1] if x else [])
df_2012 = df_2012.drop('content', axis=1)

## 필요 없는 부분 제거 (기자 이메일, 광고 ..)
from tqdm import tqdm

# 새로운 열을 생성하기 위해 빈 리스트 초기화
new_sentences = []

for i in tqdm(range(len(df_2012))):
    res = []
    for j in range(len(df_2012['sentences'].iloc[i])):
        if re.search(r'<.*?>', df_2012['sentences'].iloc[i][j]) or ('@' in df_2012['sentences'].iloc[i][j]):
            break
        else:
            res.append(df_2012['sentences'].iloc[i][j])
    # 각 행에 대한 결과를 빈 리스트에 추가
    new_sentences.append(res)

# 새로운 열로 할당
df_2012['new_sentences'] = new_sentences

# new_sentences 열에 있는 각 문장들을 하나의 문서로 합침
merged_documents = []

for sentences in df_2012['new_sentences']:
    merged_document = ' '.join(sentences)
    merged_documents.append(merged_document)

# 컬럼 추가
df_2012['new_content'] = merged_documents
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 28431/28431 [00:07<00:00, 3645.87it/s]

# %%
## 너무 별로
from konlpy.tag import Kkma
from tqdm import tqdm

# Kkma 객체 생성
kkma = Kkma()

# 데이터프레임의 각 행에 대해 형태소 분석을 수행하고 결과를 리스트에 저장
results = []
texts = df_2012['new_content']

for text in tqdm(texts):
    try:
        result = kkma.morphs(text)
        results.append(result)
    except Exception as e:
        print(f"Error occurred for text: {text}")
        print(f"Error message: {e}")
        continue

# 결과를 데이터프레임에 추가
df_2012['morphs_kkma'] = results
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 28431/28431 [1:28:05<00:00,  5.38it/s]

# %%
df_2012['morphs_kkma'][0]
# Out:
# ['[',
#  '한겨레',
#  ']',
#  '소득세',
#  '최고',
#  '구간',
#  '반대',
#  '거슬러',
#  '하',
#  'ㄴ',
#  '나라',
#  '당',
#  '의원',
#  '들',
#  '본회',
#  '의',
#  '표결',
#  '박근',
#  '혜',
#  '‘',
#  '변화',
#  '되',
#  'ㄴ',
#  '위상',
#  '’',
#  '드러나',
#  '한나라당',
#  '안',
#  '에서',
#  '‘',
#  '박근',
#  '혜의',
#  '뜻',
#  '’',
#  '에',
#  '브레이크',
#  '가',
#  '걸리',
#  '었',
#  '다',
#  '.',
#  '박근',
#  '혜',
#  '비상',
#  '대책',
#  '위원',
#  '장이',
#  '부정적',
#  '이',
#  'ㄴ',
#  '뜻',
#  '을',
#  '나타내',
#  'ㄴ',
#  '소득세',
#  '최고',
#  '구간',
#  '신설',
#  '안',
#  '(',
#  '일명',
#  '버핏',
#  '세',
#  ')',
#  '이',
#  '결국',
#  '여야',
#  '합의',
#  '로',
#  '지난달',
#  '31',
#  '일',
#  '국회',
#  '본회의',
#  '에서',
#  '처리',
#  '되',
#  '었',
#  '기',
#  '때문',
#  '이',
#  '다',
#  '.',
#  '서울',
#  '의',
#  '한',
#  '의원',
#  '은',
#  '“',
#  '부자',
#  '증세',
#  '도',
#  '의미',
#  '가',
#  '있',
#  '지만',
#  '한나라',
#  '당',
#  '에서',
#  '박근',
#  '혜',
#  '위원장',
#  '뜻대로',
#  '안',
#  '되',
#  '는',
#  '일',
#  '이',
#  '있',
#  '다는',
#  '것',
#  '을',
#  '알려주',
#  'ㄴ',
#  '의미',
# ...

# %% [markdown]
# ### Hannanum

# %%
import pandas as pd
df_2012 = pd.read_csv('2012_news.csv')

## 역슬래시가 포함된 단어 변경
import re

def replace_backslash_with_space(text):
    # 정규표현식을 사용하여 역슬래시를 공백으로 대체
    clean_text = re.sub(r'[\\n\s]+', ' ', text)
    return clean_text

# 역슬래시를 공백으로 변경한 결과를 새로운 열에 저장
df_2012['content'] = df_2012['content'].apply(replace_backslash_with_space)

## 문장 토큰화
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
df_2012['sentences'] = df_2012['content'].apply(tokenize_sentences)
df_2012['sentences'] = df_2012['sentences'].apply(lambda x: x[:-1] if x else [])
df_2012 = df_2012.drop('content', axis=1)

## 필요 없는 부분 제거 (기자 이메일, 광고 ..)
from tqdm import tqdm

# 새로운 열을 생성하기 위해 빈 리스트 초기화
new_sentences = []

for i in tqdm(range(len(df_2012))):
    res = []
    for j in range(len(df_2012['sentences'].iloc[i])):
        if re.search(r'<.*?>', df_2012['sentences'].iloc[i][j]) or ('@' in df_2012['sentences'].iloc[i][j]):
            break
        else:
            res.append(df_2012['sentences'].iloc[i][j])
    # 각 행에 대한 결과를 빈 리스트에 추가
    new_sentences.append(res)

# 새로운 열로 할당
df_2012['new_sentences'] = new_sentences

# new_sentences 열에 있는 각 문장들을 하나의 문서로 합침
merged_documents = []

for sentences in df_2012['new_sentences']:
    merged_document = ' '.join(sentences)
    merged_documents.append(merged_document)

# 컬럼 추가
df_2012['new_content'] = merged_documents
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 28431/28431 [00:04<00:00, 6114.76it/s]

# %%
## 괜춘
from konlpy.tag import Hannanum
from tqdm import tqdm

# Hannanum 객체 생성
hannanum = Hannanum()

# 데이터프레임의 각 행에 대해 형태소 분석을 수행하고 결과를 리스트에 저장
results = []
texts = df_2012['new_content']

for text in tqdm(texts):
    try:
        result = hannanum.morphs(text)
        results.append(result)
    except Exception as e:
        print(f"Error occurred for text: {text}")
        print(f"Error message: {e}")
        continue

# 결과를 데이터프레임에 추가
df_2012['morphs_Hannanum'] = results
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 28431/28431 [20:32<00:00, 23.07it/s]

# %%
df_2012['morphs_Hannanum'][0]
# Out:
# ['[한겨레]',
#  '소득세',
#  '최고구간',
#  '반대',
#  '거슬러한나라당',
#  '의원들',
#  '본회',
#  '의',
#  '표결박근혜',
#  '‘변화된',
#  '위상’',
#  '드러나',
#  '아',
#  '한나라당',
#  '안',
#  '에서',
#  '‘박근혜',
#  '의',
#  '뜻’',
#  '에',
#  '브레이크',
#  '가',
#  '걸리',
#  '었다',
#  '.',
#  '박근혜',
#  '비상대책위원장',
#  '이',
#  '부정적',
#  '이',
#  'ㄴ',
#  '뜻',
#  '을',
#  '나타내',
#  'ㄴ',
#  '소득세',
#  '최고구간',
#  '신설',
#  '안',
#  '(',
#  '일명',
#  '버핏세)',
#  '이',
#  '결국',
#  '여',
#  '이',
#  '야',
#  '합의',
#  '로',
#  '지난달',
#  '31일',
#  '국회',
#  '본회의',
#  '에서',
#  '처리',
#  '되',
#  '었기',
#  '때문',
#  '이',
#  '다',
#  '.',
#  '서울',
#  '의',
#  '하',
#  'ㄴ',
#  '의원',
#  '은',
#  '“부자증세',
#  '도',
#  '의미',
#  '가',
#  '있',
#  '지',
#  '말',
#  'ㄴ',
#  '한나라당',
#  '에서',
#  '박근혜',
#  '위원장',
#  '뜻',
#  '대로',
#  '안',
#  '되',
#  '는',
#  '일',
#  '이',
#  '있',
#  '다는',
#  '거',
#  'ㄹ',
#  '알리',
#  '어',
#  '주',
#  'ㄴ',
#  '의미',
#  '가',
#  '더',
#  '크다”고',
#  '말',
#  '하',
#  '었다',
#  '.',
#  '한나라당',
#  '일부',
#  '의원들',
#  '이',
#  '박근혜',
#  '위원장',
#  '의',
#  '뜻',
#  '을',
# ...

# %% [markdown]
# ### Soynlp

# %%
import pandas as pd
df_2012 = pd.read_csv('2012_news.csv')

## 역슬래시가 포함된 단어 변경
import re

def replace_backslash_with_space(text):
    # 정규표현식을 사용하여 역슬래시를 공백으로 대체
    clean_text = re.sub(r'[\\n\s]+', ' ', text)
    return clean_text

# 역슬래시를 공백으로 변경한 결과를 새로운 열에 저장
df_2012['content'] = df_2012['content'].apply(replace_backslash_with_space)

## 문장 토큰화
from nltk import sent_tokenize
import pandas as pd
import nltk

# nltk의 필요한 데이터 다운로드
#nltk.download('punkt')

# 문장 토큰화 함수 정의
def tokenize_sentences(text):
    return sent_tokenize(text)

# 'content' 열의 데이터에 대해 문장 토큰화를 적용하여 새로운 열에 추가
df_2012['sentences'] = df_2012['content'].apply(tokenize_sentences)
df_2012['sentences'] = df_2012['sentences'].apply(lambda x: x[:-1] if x else [])
df_2012 = df_2012.drop('content', axis=1)

## 필요 없는 부분 제거 (기자 이메일, 광고 ..)
from tqdm import tqdm

# 새로운 열을 생성하기 위해 빈 리스트 초기화
new_sentences = []

for i in tqdm(range(len(df_2012))):
    res = []
    for j in range(len(df_2012['sentences'].iloc[i])):
        if re.search(r'<.*?>', df_2012['sentences'].iloc[i][j]) or ('@' in df_2012['sentences'].iloc[i][j]):
            break
        else:
            res.append(df_2012['sentences'].iloc[i][j])
    # 각 행에 대한 결과를 빈 리스트에 추가
    new_sentences.append(res)

# 새로운 열로 할당
df_2012['new_sentences'] = new_sentences

# new_sentences 열에 있는 각 문장들을 하나의 문서로 합침
merged_documents = []

for sentences in df_2012['new_sentences']:
    merged_document = ' '.join(sentences)
    merged_documents.append(merged_document)

# 컬럼 추가
df_2012['new_content'] = merged_documents
# Out:
# 100%|██████████████████████████████████| 28431/28431 [00:01<00:00, 19087.04it/s]

# %%
#pip install soynlp

# %%
## 제일 괜찮
from soynlp.tokenizer import MaxScoreTokenizer
from tqdm import tqdm

# MaxScoreTokenizer 객체 생성
tokenizer = MaxScoreTokenizer()

# 데이터프레임의 각 행에 대해 형태소 분석을 수행하고 결과를 리스트에 저장
results = []
texts = df_2012['new_content']

for text in tqdm(texts):
    try:
        result = tokenizer.tokenize(text)
        results.append(result)
    except Exception as e:
        print(f"Error occurred for text: {text}")
        print(f"Error message: {e}")
        continue

# 결과를 데이터프레임에 추가
df_2012['morphs_MaxScoreTokenizer'] = results
# Out:
# 100%|███████████████████████████████████| 28431/28431 [00:08<00:00, 3279.75it/s]

# %%
df_2012['morphs_MaxScoreTokenizer'][0]
# Out:
# ['[한겨레]',
#  '소득세',
#  '최고구간',
#  '반대',
#  '거슬러한나라당',
#  '의원들',
#  '본회의',
#  '표결박근혜',
#  '‘변화된',
#  '위상’',
#  '드러나',
#  '한나라당',
#  '안에서',
#  '‘박근혜의',
#  '뜻’에',
#  '브레이크가',
#  '걸렸다.',
#  '박근혜',
#  '비상대책위원장이',
#  '부정적인',
#  '뜻을',
#  '나타낸',
#  '소득세',
#  '최고구간',
#  '신설안(일명',
#  '버핏세)이',
#  '결국',
#  '여야',
#  '합의로',
#  '지난달',
#  '31일',
#  '국회',
#  '본회의에서',
#  '처리됐기',
#  '때문이다.',
#  '서울의',
#  '한',
#  '의원은',
#  '“부자증세도',
#  '의미가',
#  '있지만',
#  '한나라당에서',
#  '박근혜',
#  '위원장',
#  '뜻대로',
#  '안',
#  '되는',
#  '일이',
#  '있다는',
#  '걸',
#  '알려준',
#  '의미가',
#  '더',
#  '크다”고',
#  '말했다.',
#  '한나라당',
#  '일부',
#  '의원들이',
#  '박근혜',
#  '위원장의',
#  '뜻을',
#  '거슬러',
#  '야당과',
#  '공동으로',
#  '소득세법',
#  '개정안',
#  '수정안을',
#  '제출한',
#  '것',
#  '자체가',
#  '박',
#  '위원장의',
#  '변화된',
#  '당내',
#  '위상을',
#  '반영한다는',
#  '해석이다.',
#  '정두언',
#  '의원은',
#  '지난',
#  '31일',
#  '의총에서',
#  '“왜',
#  '다수',
#  '의원이',
#  '바라는',
#  '데',
#  '박',
#  '비대위원장이',
#  '일방적으로',
#  '안',
#  '된다고',
#  '하느냐.',
#  '이렇게',
#  '밀어붙이면',
#  '탈당하겠다”며',
# ...

# %%
df_2012['new_sentences'][0]
# Out:
# ['[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위상’ 드러나 한나라당 안에서 ‘박근혜의 뜻’에 브레이크가 걸렸다.',
#  '박근혜 비상대책위원장이 부정적인 뜻을 나타낸 소득세 최고구간 신설안(일명 버핏세)이 결국 여야 합의로 지난달 31일 국회 본회의에서 처리됐기 때문이다.',
#  '서울의 한 의원은 “부자증세도 의미가 있지만 한나라당에서 박근혜 위원장 뜻대로 안 되는 일이 있다는 걸 알려준 의미가 더 크다”고 말했다.',
#  '한나라당 일부 의원들이 박근혜 위원장의 뜻을 거슬러 야당과 공동으로 소득세법 개정안 수정안을 제출한 것 자체가 박 위원장의 변화된 당내 위상을 반영한다는 해석이다.',
#  '정두언 의원은 지난 31일 의총에서 “왜 다수 의원이 바라는 데 박 비대위원장이 일방적으로 안 된다고 하느냐.',
#  '이렇게 밀어붙이면 탈당하겠다”며 박 위원장을 압박한 것으로 알려졌다.',
#  '박 위원장은 이날 밤 열린 본회의에서 소득세 최고구간 신설 표결에 참여하지 않으며 불편한 심기를 표시했다.',
#  '박 위원장은 자본소득 과세 강화 등을 포함하는 부자증세 방안을 총선 공약으로 제시할 계획이었지만 소득세 최고구간 신설로 정책수정이 불가피해졌다.',
#  '한 서울 초선 의원은 “자신이 거부한 안이 다시 튀어나와 통과된 셈이다.',
#  '이젠 특정인이 대세를 막을 수 없다는 게 증명된 것”이라며 “박 위원장으로선 아픈 대목일 것”이라고 말했다.',
#  '정두언 의원은 이날 자신의 트위터에 “박근혜 체제에서 부정적으로 바뀐 기류를 되살리느나 혼신의 힘을 다했다.',
#  '민심을 업으면 어떤 벽도 넘을 수 있다는 사실을 다시 확인했다”고 글을 올렸다.',
#  '당내에선 박 위원장 중심의 비대위에 대한 불만이 소득세 최고구간 표결에 반영된 것이란 분석도 나온다.',
# ...

# %%
df_2012_test = pd.read_csv('2012_news.csv')
df_2012_test['content'][0]
# Out:
# '[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위상’ 드러나 한나라당 안에서 ‘박근혜의 뜻’에 브레이크가 걸렸다. 박근혜 비상대책위원장이 부정적인 뜻을 나타낸 소득세 최고구간 신설안(일명 버핏세)이 결국 여야 합의로 지난달 31일 국회 본회의에서 처리됐기 때문이다.  서울의 한 의원은 “부자증세도 의미가 있지만 한나라당에서 박근혜 위원장 뜻대로 안 되는 일이 있다는 걸 알려준 의미가 더 크다”고 말했다. 한나라당 일부 의원들이 박근혜 위원장의 뜻을 거슬러 야당과 공동으로 소득세법 개정안 수정안을 제출한 것 자체가 박 위원장의 변화된 당내 위상을 반영한다는 해석이다. 정두언 의원은 지난 31일 의총에서 “왜 다수 의원이 바라는 데 박 비대위원장이 일방적으로 안 된다고 하느냐. 이렇게 밀어붙이면 탈당하겠다”며 박 위원장을 압박한 것으로 알려졌다. 박 위원장은 이날 밤 열린 본회의에서 소득세 최고구간 신설 표결에 참여하지 않으며 불편한 심기를 표시했다. 박 위원장은 자본소득 과세 강화 등을 포함하는 부자증세 방안을 총선 공약으로 제시할 계획이었지만 소득세 최고구간 신설로 정책수정이 불가피해졌다. 한 서울 초선 의원은 “자신이 거부한 안이 다시 튀어나와 통과된 셈이다. 이젠 특정인이 대세를 막을 수 없다는 게 증명된 것”이라며 “박 위원장으로선 아픈 대목일 것”이라고 말했다. 정두언 의원은 이날 자신의 트위터에 “박근혜 체제에서 부정적으로 바뀐 기류를 되살리느나 혼신의 힘을 다했다. 민심을 업으면 어떤 벽도 넘을 수 있다는 사실을 다시 확인했다”고 글을 올렸다.  당내에선 박 위원장 중심의 비대위에 대한 불만이 소득세 최고구간 표결에 반영된 것이란 분석도 나온다. 실제 31일 의총에선 친이계인 권택기, 장제원, 권성동 의원 등이 김종인 비대위원과 이상돈 비대위원에 대해 각각 과거 동화은행 뇌물수수 사건으로 유죄판결을 받았다는 점과 천안함 사건 직후 북한 소행 가능성을 배제했다는 점을 들어 사퇴를 요구했다. 그러나 김종인 위원은 
# ...

# %%
df_2012.iloc[2335]
# Out:
# title                                     광주시-국회의원 국비지원 정책협의
# content    광주시-국회의원, 정책협의회\n  \n    (광주=연합뉴스) 강운태 광주시장과 지...
# Name: 2335, dtype: object

# %%
df_2012['new_sentences'][2386]
# Out:
# ['[ 뉴스1 제공 ](서울=뉴스1) 이정선 인턴기자 = 2012년 대한민국 교육계 신년교례회가 열린 10일 오전 서울 세종문화회관 세종홀에서 황우여 한나라당 원내대표가 인사말을 하고 있다.']

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mit06\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
from konlpy.corpus import kobill
from collections import Counter

# NLTK에서 한국어 스톱 워드 리스트 다운로드
nltk.download('stopwords')

# NLTK에서 다운로드한 한국어 스톱 워드 리스트를 불러옴
stopwords = set(stopwords.words('korean'))

# 예시 텍스트
text = '오늘은 한국어 자연어 처리를 공부하는 날입니다. 어떤 단어들이 스톱 워드로 제거되는지 확인해봅시다.'

# 예시 텍스트에서 스톱 워드를 제거합니다.
words = text.split()
filtered_words = [word for word in words if word not in stopwords]

# 결과 출력
print('원본 텍스트:', text)
print('스톱 워드 제거 후:', ' '.join(filtered_words))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mit06\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[27], line 10
#       7 nltk.download('stopwords')
#       9 # NLTK에서 다운로드한 한국어 스톱 워드 리스트를 불러옴
# ---> 10 stopwords = set(stopwords.words('korean'))
#      12 # 예시 텍스트
#      13 text = '오늘은 한국어 자연어 처리를 공부하는 날입니다. 어떤 단어들이 스톱 워드로 제거되는지 확인해봅시다.'
#
# File ~\anaconda3\Lib\site-packages\nltk\corpus\reader\wordlist.py:21, in WordListCorpusReader.words(self, fileids, ignore_lines_startswith)
#      18 def words(self, fileids=None, ignore_lines_startswith="\n"):
#      19     return [
#      20         line
# ---> 21         for line in line_tokenize(self.raw(fileids))
#      22         if not line.startswith(ignore_lines_startswith)
#      23     ]
#
# ...

# %% [markdown]
# pip install google-cloud-translate

# %% [markdown]
# pip install afinn

# %%
from google.cloud import translate_v2 as translate
from afinn import Afinn

# Google Cloud Translation API 인증 정보 설정
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = ""

# Google Cloud Translation API를 이용하여 영어로된 AFINN 감정 사전을 한글로 번역하는 함수
def translate_afinn_to_korean():
    translate_client = translate.Client()
    afinn_english = Afinn()
    afinn_english_dict = afinn_english._dict
    
    afinn_korean = {}
    for word, score in afinn_english_dict.items():
        result = translate_client.translate(word, source_language='en', target_language='ko')
        korean_word = result['translatedText']
        afinn_korean[korean_word] = score
    return afinn_korean


# 한글로 번역된 AFINN 감정 사전 로드
afinn_korean = translate_afinn_to_korean()

# 뉴스 본문 (한글)
korean_news = "이 기사는 세계에서 일어나는 다양한 사건들에 대해 이야기합니다."

# AFINN 감정 분석기 초기화
afinn = Afinn(language='korean', emoticons=True)

# 번역된 한글 뉴스 본문에 대해 AFINN 감정 점수 계산
sentiment_score = afinn.score(korean_news)

# 감정 점수를 기반으로 뉴스 본문을 긍정 또는 부정으로 분류
if sentiment_score > 0:
    sentiment = '긍정'
elif sentiment_score < 0:
    sentiment = '부정'
else:
    sentiment = '중립'

# 결과 출력
print("뉴스 본문:", korean_news)
print("감정:", sentiment)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[6], line 23
#      19     return afinn_korean
#      22 # 한글로 번역된 AFINN 감정 사전 로드
# ---> 23 afinn_korean = translate_afinn_to_korean()
#      25 # 뉴스 본문 (한글)
#      26 korean_news = "이 기사는 세계에서 일어나는 다양한 사건들에 대해 이야기합니다."
#
# Cell In[6], line 16, in translate_afinn_to_korean()
#      14 afinn_korean = {}
#      15 for word, score in afinn_english_dict.items():
# ---> 16     result = translate_client.translate(word, source_language='en', target_language='ko')
#      17     korean_word = result['translatedText']
#      18     afinn_korean[korean_word] = score
#
# File ~/anaconda3/lib/python3.11/site-packages/google/cloud/translate_v2/client.py:265, in Client.translate(self, values, target_language, format_, source_language, customization_ids, model)
#     254     customization_ids = [customization_ids]
#     256 data = {
# ...

# %% [markdown]
# # 한글 감성사전  KNU를 이용한 감성 sentiment 분석

# %% [markdown]
# ## 한글 감성어 사전(KNU) 업로드

# %%
import json
import pandas as pd

with open('SentiWord_info.json', encoding='utf-8-sig', mode='r') as f: 
  SentiWord_info = json.load(f)

sentiword_dic = pd.DataFrame(SentiWord_info)
sentiword_dic
# Out:
#          word word_root polarity
# 0         (-;         (        1
# 1       (;_;)     (;_;)       -1
# 2        (^^)      (^^)        1
# 3       (^-^)     (^-^)        1
# 4        (^^*         (        1
# ...       ...       ...      ...
# 14838  반신반의하다      반신반의        0
# 14839    신비롭다        신비        1
# 14840   아리송하다       아리송       -1
# 14841    알쏭하다       알쏭하       -1
# 14842  알쏭달쏭하다      알쏭달쏭       -1
#
# [14843 rows x 3 columns]

# %% [markdown]
# ## 토큰화된 문장과 감성사전 비교

# %%
import pandas as pd
from tqdm import tqdm

df = pd.DataFrame(columns=("sentences", "sentiment")) 
idx = 0
 
for sentence in tqdm(df_2012['new_sentences'][0]):             
  sentiment = 0                                     
  for i in range(0, len(sentiword_dic)):
    if sentiword_dic.word[i] in sentence:
      sentiment += int(sentiword_dic.polarity[i])
  df.loc[idx] = [sentence, sentiment]
  idx += 1 
    
df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00,  9.04it/s]
#                                             sentences  sentiment
# 0   [한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위...          1
# 1   박근혜 비상대책위원장이 부정적인 뜻을 나타낸 소득세 최고구간 신설안(일명 버핏세)이...         -3
# 2   서울의 한 의원은 “부자증세도 의미가 있지만 한나라당에서 박근혜 위원장 뜻대로 안 ...          2
# 3   한나라당 일부 의원들이 박근혜 위원장의 뜻을 거슬러 야당과 공동으로 소득세법 개정안...         -2
# 4   정두언 의원은 지난 31일 의총에서 “왜 다수 의원이 바라는 데 박 비대위원장이 일...          0
# 5              이렇게 밀어붙이면 탈당하겠다”며 박 위원장을 압박한 것으로 알려졌다.         -1
# 6   박 위원장은 이날 밤 열린 본회의에서 소득세 최고구간 신설 표결에 참여하지 않으며 ...          1
# 7   박 위원장은 자본소득 과세 강화 등을 포함하는 부자증세 방안을 총선 공약으로 제시할...          0
# 8            한 서울 초선 의원은 “자신이 거부한 안이 다시 튀어나와 통과된 셈이다.          0
# 9   이젠 특정인이 대세를 막을 수 없다는 게 증명된 것”이라며 “박 위원장으로선 아픈 ...         -2
# 10  정두언 의원은 이날 자신의 트위터에 “박근혜 체제에서 부정적으로 바뀐 기류를 되살리...         -2
# 11       민심을 업으면 어떤 벽도 넘을 수 있다는 사실을 다시 확인했다”고 글을 올렸다.          0
# ...

# %%
import pandas as pd
from tqdm import tqdm
import re

# 결과를 저장할 빈 리스트 생성
extracted_words = []

# 각 행에 대해 반복
for news in tqdm(df_2012['new_sentences'][0]):
    # 정규 표현식을 사용하여 '당'으로 끝나는 단어 또는 '의원' 앞에 있는 단어 추출
    words = re.findall(r'\b(\w+당 | \w+(?=\s의원))', news)
    # 추출된 단어 리스트를 하나의 문자열로 변환하여 저장
    extracted_words.append(', '.join(words))

# 데이터프레임에 새로운 열로 추가
words
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 15036.94it/s]
# []

# %%
## 기사내용 중 당이나 위원 이름 함께 추출

import pandas as pd
from tqdm import tqdm
import re

df = pd.DataFrame(columns=("sentences", "sentiment")) 
idx = 0
extracted_words = []  # 결과를 저장할 빈 리스트 생성
 
for sentence in tqdm(df_2012['new_sentences'][0]):             
    sentiment = 0                                     
    for i in range(0, len(sentiword_dic)):
        if sentiword_dic.word[i] in sentence:
            sentiment += int(sentiword_dic.polarity[i])
    # 데이터프레임에 문장과 감성 추가
    df.loc[idx] = [sentence, sentiment]
    idx += 1 
    
    # 정규 표현식을 사용하여 '당'으로 끝나는 단어 또는 '의원' 앞에 있는 단어 추출
    words = re.findall(r'\b(\w+당|\w+(?=\s의원)|\w+(?=\s위원)|\w+(?=\s비대위원)|\w+(?=\s위원장)|\w+(?=\s비상대책위원장))', sentence)
    # 추출된 단어 리스트를 하나의 문자열로 변환하여 저장
    extracted_words.append(', '.join(words))

# 데이터프레임에 추출된 단어 컬럼 추가
df['extracted_words'] = extracted_words

df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00,  9.11it/s]
#                                             sentences  sentiment  \
# 0   [한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위...          1
# 1   박근혜 비상대책위원장이 부정적인 뜻을 나타낸 소득세 최고구간 신설안(일명 버핏세)이...         -3
# 2   서울의 한 의원은 “부자증세도 의미가 있지만 한나라당에서 박근혜 위원장 뜻대로 안 ...          2
# 3   한나라당 일부 의원들이 박근혜 위원장의 뜻을 거슬러 야당과 공동으로 소득세법 개정안...         -2
# 4   정두언 의원은 지난 31일 의총에서 “왜 다수 의원이 바라는 데 박 비대위원장이 일...          0
# 5              이렇게 밀어붙이면 탈당하겠다”며 박 위원장을 압박한 것으로 알려졌다.         -1
# 6   박 위원장은 이날 밤 열린 본회의에서 소득세 최고구간 신설 표결에 참여하지 않으며 ...          1
# 7   박 위원장은 자본소득 과세 강화 등을 포함하는 부자증세 방안을 총선 공약으로 제시할...          0
# 8            한 서울 초선 의원은 “자신이 거부한 안이 다시 튀어나와 통과된 셈이다.          0
# 9   이젠 특정인이 대세를 막을 수 없다는 게 증명된 것”이라며 “박 위원장으로선 아픈 ...         -2
# 10  정두언 의원은 이날 자신의 트위터에 “박근혜 체제에서 부정적으로 바뀐 기류를 되살리...         -2
# 11       민심을 업으면 어떤 벽도 넘을 수 있다는 사실을 다시 확인했다”고 글을 올렸다.          0
# ...

# %%
import pandas as pd
from tqdm import tqdm
import re

df = pd.DataFrame(columns=("sentences", "sentiment")) 
idx = 0
extracted_words = []  # 결과를 저장할 빈 리스트 생성
 
for sentence in tqdm(df_2012['new_sentences'][0]):             
    sentiment = 0                                     
    for i in range(0, len(sentiword_dic)):
        if sentiword_dic.word[i] in sentence:
            sentiment += int(sentiword_dic.polarity[i])
    # 데이터프레임에 문장과 감성 추가
    df.loc[idx] = [sentence, sentiment]
    idx += 1 
    
    # 정규 표현식을 사용하여 '당'으로 끝나는 단어 또는 '의원' 앞에 있는 단어 추출
    words = re.findall(r'\b(\w+당|\w+(?=\s의원)|\w+(?=\s위원)|\w+(?=\s비대위원)|\w+(?=\s위원장)|\w+(?=\s비상대책위원장))', sentence)
    # 추출된 단어 리스트를 하나의 문자열로 변환하여 저장
    extracted_words.append(', '.join(words))

# 데이터프레임에 추출된 단어 컬럼 추가
df['extracted_words'] = extracted_words

# 추출된 단어와 감성 점수를 결합하여 하나의 문자열로 만듦
combined_results = [(words, sentiment) for words, sentiment in zip(df['extracted_words'], df['sentiment'])]
# 결과를 하나의 행으로 저장
result_row = {
    'result': ', '.join([f"({words}, {sentiment})" for words, sentiment in combined_results]),
}
result_df = pd.DataFrame([result_row])

result_df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00,  8.95it/s]
#                                               result
# 0  (거슬러한나라당, 한나라당, 1), (박근혜, -3), (한, 한나라당, 박근혜, ...

# %%
import pandas as pd
from tqdm import tqdm
import re

df = pd.DataFrame(columns=("sentences", "sentiment")) 
idx = 0
extracted_words = []  # 결과를 저장할 빈 리스트 생성
 
for sentence in tqdm(df_2012['new_sentences'][0]):             
    sentiment = 0                                     
    for i in range(0, len(sentiword_dic)):
        if sentiword_dic.word[i] in sentence:
            sentiment += int(sentiword_dic.polarity[i])
    # 데이터프레임에 문장과 감성 추가
    df.loc[idx] = [sentence, sentiment]
    idx += 1 
    
    # 정규 표현식을 사용하여 '당'으로 끝나는 단어 또는 '의원' 앞에 있는 단어 추출
    words = re.findall(r'\b(\w+당|\w+(?=\s의원)|\w+(?=\s위원)|\w+(?=\s비대위원)|\w+(?=\s위원장)|\w+(?=\s비상대책위원장))', sentence)
    # 추출된 단어 리스트를 하나의 문자열로 변환하여 저장
    extracted_words.append(', '.join(words))

# 데이터프레임에 추출된 단어 컬럼 추가
df['extracted_words'] = extracted_words

# 하나의 행으로 결과 저장
result_row = {
    'sentences': ', '.join(df['sentences']),
    'sentiment': sum(df['sentiment']),
    'extracted_words': ', '.join(df['extracted_words'])
}
result_df = pd.DataFrame([result_row])

result_df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00,  9.03it/s]
#                                            sentences  sentiment  \
# 0  [한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위...        -15
#
#                                      extracted_words
# 0  거슬러한나라당, 한나라당, 박근혜, 한, 한나라당, 박근혜, 한나라당, 일부, 박근...

# %%
## 원하던 데이터프레임 추출완

import pandas as pd
from tqdm import tqdm
import re

# 기사 내용 및 감성 정보를 저장할 데이터프레임 생성
df = pd.DataFrame(columns=("sentences", "sentiment")) 
idx = 0
extracted_words = []  # 결과를 저장할 빈 리스트 생성
 
for sentence in tqdm(df_2012['new_sentences'][0]):             
    sentiment = 0                                     
    for i in range(0, len(sentiword_dic)):
        if sentiword_dic.word[i] in sentence:
            sentiment += int(sentiword_dic.polarity[i])
    # 데이터프레임에 문장과 감성 추가
    df.loc[idx] = [sentence, sentiment]
    idx += 1 
    
    # 정규 표현식을 사용하여 '당'으로 끝나는 단어 또는 '의원' 앞에 있는 단어 추출
    words = re.findall(r'\b(\w+당|\w+(?=\s의원)|\w+(?=\s위원)|\w+(?=\s비대위원)|\w+(?=\s위원장)|\w+(?=\s비상대책위원장))', sentence)
    # 추출된 단어 리스트를 하나의 문자열로 변환하여 저장
    extracted_words.append(', '.join(words))

# 데이터프레임에 추출된 단어 컬럼 추가
df['extracted_words'] = extracted_words

# 추출된 단어와 감성 점수를 결합하여 하나의 문자열로 만듦
combined_results = [(words, sentiment) for words, sentiment in zip(df['extracted_words'], df['sentiment'])]
# 결과를 하나의 행으로 저장
result_row = {
    'article': ', '.join(df_2012['new_sentences'][0]),
    'result': ', '.join([f"({words}, {sentiment})" for words, sentiment in combined_results]),
}
result_df = pd.DataFrame([result_row])

result_df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 15/15 [00:01<00:00,  9.13it/s]
#                                              article  \
# 0  [한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위...
#
#                                               result
# 0  (거슬러한나라당, 한나라당, 1), (박근혜, -3), (한, 한나라당, 박근혜, ...

# %%
pd.set_option('display.max_colwidth', None)
result_df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# ## 최종이고싶은

# %%
import pandas as pd
from tqdm import tqdm
import re

# 결과를 저장할 리스트 생성
result_list = []

# 데이터프레임의 모든 행에 대해 반복
for i in tqdm(range(len(df_2012['new_sentences']))):
    # 기사 내용 및 감성 정보를 저장할 데이터프레임 생성
    df = pd.DataFrame(columns=("sentences", "sentiment")) 
    idx = 0
    extracted_words = []  # 결과를 저장할 빈 리스트 생성

    for sentence in df_2012['new_sentences'][i]:             
        sentiment = 0                                     
        for j in range(0, len(sentiword_dic)):
            if sentiword_dic.word[j] in sentence:
                sentiment += int(sentiword_dic.polarity[j])
        # 데이터프레임에 문장과 감성 추가
        df.loc[idx] = [sentence, sentiment]
        idx += 1 

        # 정규 표현식을 사용하여 '당'으로 끝나는 단어 또는 '의원' 앞에 있는 단어 추출
        words = re.findall(r'\b(\w+당|\w+(?=\s의원)|\w+(?=\s위원)|\w+(?=\s비대위원)|\w+(?=\s위원장)|\w+(?=\s비상대책위원장))', sentence)
        # 추출된 단어 리스트를 하나의 문자열로 변환하여 저장
        extracted_words.append(', '.join(words))
    
    # 데이터프레임에 추출된 단어 컬럼 추가
    df['extracted_words'] = extracted_words

    # 추출된 단어와 감성 점수를 결합하여 하나의 문자열로 만듦
    combined_results = [(words, sentiment) for words, sentiment in zip(df['extracted_words'], df['sentiment'])]
    # 결과를 하나의 행으로 저장
    result_row = {
        'article': ', '.join(df_2012['new_sentences'][i]),
        'result': ', '.join([f"({words}, {sentiment})" for words, sentiment in combined_results]),
    }
    result_list.append(result_row)

# 결과 리스트를 데이터프레임으로 변환
result_df = pd.DataFrame(result_list)

result_df
# Out:
#  98%|████████████████████████████████████████████████████████████████████████▍ | 27814/28431 [4:55:59<05:00,  2.05it/s]

# %%
df_2012['new_sentences'][0]
# Out:
# ['[한겨레] 소득세 최고구간 반대 거슬러한나라당 의원들 본회의 표결박근혜 ‘변화된 위상’ 드러나 한나라당 안에서 ‘박근혜의 뜻’에 브레이크가 걸렸다.',
#  '박근혜 비상대책위원장이 부정적인 뜻을 나타낸 소득세 최고구간 신설안(일명 버핏세)이 결국 여야 합의로 지난달 31일 국회 본회의에서 처리됐기 때문이다.',
#  '서울의 한 의원은 “부자증세도 의미가 있지만 한나라당에서 박근혜 위원장 뜻대로 안 되는 일이 있다는 걸 알려준 의미가 더 크다”고 말했다.',
#  '한나라당 일부 의원들이 박근혜 위원장의 뜻을 거슬러 야당과 공동으로 소득세법 개정안 수정안을 제출한 것 자체가 박 위원장의 변화된 당내 위상을 반영한다는 해석이다.',
#  '정두언 의원은 지난 31일 의총에서 “왜 다수 의원이 바라는 데 박 비대위원장이 일방적으로 안 된다고 하느냐.',
#  '이렇게 밀어붙이면 탈당하겠다”며 박 위원장을 압박한 것으로 알려졌다.',
#  '박 위원장은 이날 밤 열린 본회의에서 소득세 최고구간 신설 표결에 참여하지 않으며 불편한 심기를 표시했다.',
#  '박 위원장은 자본소득 과세 강화 등을 포함하는 부자증세 방안을 총선 공약으로 제시할 계획이었지만 소득세 최고구간 신설로 정책수정이 불가피해졌다.',
#  '한 서울 초선 의원은 “자신이 거부한 안이 다시 튀어나와 통과된 셈이다.',
#  '이젠 특정인이 대세를 막을 수 없다는 게 증명된 것”이라며 “박 위원장으로선 아픈 대목일 것”이라고 말했다.',
#  '정두언 의원은 이날 자신의 트위터에 “박근혜 체제에서 부정적으로 바뀐 기류를 되살리느나 혼신의 힘을 다했다.',
#  '민심을 업으면 어떤 벽도 넘을 수 있다는 사실을 다시 확인했다”고 글을 올렸다.',
#  '당내에선 박 위원장 중심의 비대위에 대한 불만이 소득세 최고구간 표결에 반영된 것이란 분석도 나온다.',
# ...

# %%
import pandas as pd
from tqdm import tqdm
import re

df = pd.DataFrame(columns=('title', "article")) 
idx = 0
sentiments = []  # 각 문장의 감성 값을 저장할 리스트
extracted_words = []  # 각 기사에서 추출된 단어를 저장할 리스트

# 전체 데이터프레임의 길이가 아닌 처음 4개 행에 대해서만 반복
for i in tqdm(range(4)):  
    title = df_2012['title'][i]
    article = df_2012['new_sentences'][i]  # 현재 행의 문장 리스트
    sentence_sentiments = []  # 각 문장의 감성 값 리스트 초기화
    for sentence in article:  # 문장 리스트에서 각 문장에 대해 반복
        sentence_sentiment = 0  # 문장의 감성 값 초기화
        for j in range(0, len(sentiword_dic)):
            if sentiword_dic.word[j] in sentence:
                sentence_sentiment += int(sentiword_dic.polarity[j])
        sentence_sentiments.append(sentence_sentiment)  # 문장의 감성 값을 리스트에 추가
        # 정규 표현식을 사용하여 '당'으로 끝나는 단어 또는 '의원' 앞에 있는 단어 추출
        words = re.findall(r'\b(\w+당|\w+(?=\s의원)|\w+(?=\s위원)|\w+(?=\s비대위원)|\w+(?=\s위원장)|\w+(?=\s비상대책위원장))', sentence)
        # 추출된 단어 리스트를 하나의 문자열로 변환하여 저장
        extracted_words.append(', '.join(words))
    sentiments.append(sentence_sentiments)  # 문장 리스트의 감성 값 리스트를 전체 감성 값 리스트에 추가

# 데이터프레임에 새로운 열 'sentiments'를 추가하고 sentiments 리스트 할당
df['sentiments'] = sentiments
# 데이터프레임에 새로운 열 'extracted_words'를 추가하고 extracted_words 리스트 할당
df['extracted_words'] = extracted_words
# 결과를 합친 문자열로 이루어진 result 열 생성
df['result'] = df.apply(lambda row: f"{''.join(row['extracted_words'])}, {row['sentiments']}", axis=1)

# 결과 출력
print(df[['title', 'article', 'result']])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:05<00:00,  1.38s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 30
#      28 df['sentiments'] = sentiments
#      29 # 데이터프레임에 새로운 열 'extracted_words'를 추가하고 extracted_words 리스트 할당
# ---> 30 df['extracted_words'] = extracted_words
#      31 # 결과를 합친 문자열로 이루어진 result 열 생성
#      32 df['result'] = df.apply(lambda row: f"{''.join(row['extracted_words'])}, {row['sentiments']}", axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4300, in DataFrame._set_item(self, key, value)
# ...

# %%
import pandas as pd
from tqdm import tqdm
import re

df = pd.DataFrame(columns=('title', "article")) 
idx = 0
sentiments = []  # 각 문장의 감성 값을 저장할 리스트
extracted_words = []  # 각 기사에서 추출된 단어를 저장할 리스트

for i in tqdm(range(len(df_2012['new_sentences'][:4]))):  # 데이터프레임의 총 행 수만큼 반복
    title = df_2012['title'][i]
    article = df_2012['new_sentences'][i]  # 현재 행의 문장 리스트
    sentence_sentiments = []  # 각 문장의 감성 값 리스트 초기화
    for sentence in article:  # 문장 리스트에서 각 문장에 대해 반복
        sentence_sentiment = 0  # 문장의 감성 값 초기화
        for j in range(0, len(sentiword_dic)):
            if sentiword_dic.word[j] in sentence:
                sentence_sentiment += int(sentiword_dic.polarity[j])
        sentence_sentiments.append(sentence_sentiment)  # 문장의 감성 값을 리스트에 추가
        # 정규 표현식을 사용하여 '당'으로 끝나는 단어 또는 '의원' 앞에 있는 단어 추출
        words = re.findall(r'\b(\w+당|\w+(?=\s의원)|\w+(?=\s위원)|\w+(?=\s비대위원)|\w+(?=\s위원장)|\w+(?=\s비상대책위원장))', sentence)
        extracted_words.extend(words)  # 추출된 단어 리스트를 extracted_words에 추가
    sentiments.append(sentence_sentiments)  # 문장 리스트의 감성 값 리스트를 전체 감성 값 리스트에 추가

# 데이터프레임에 새로운 열 'sentiments'를 추가하고 sentiments 리스트 할당
df['sentiments'] = sentiments
# 데이터프레임에 새로운 열 'extracted_words'를 추가하고 extracted_words 리스트 할당
df['extracted_words'] = extracted_words
# 결과를 합친 문자열로 이루어진 result 열 생성
df['result'] = df.apply(lambda row: f"{''.join(row['extracted_words'])}, {row['sentiments']}", axis=1)

df
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:05<00:00,  1.38s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 28
#      26 df['sentiments'] = sentiments
#      27 # 데이터프레임에 새로운 열 'extracted_words'를 추가하고 extracted_words 리스트 할당
# ---> 28 df['extracted_words'] = extracted_words
#      29 # 결과를 합친 문자열로 이루어진 result 열 생성
#      30 df['result'] = df.apply(lambda row: f"{''.join(row['extracted_words'])}, {row['sentiments']}", axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4300, in DataFrame._set_item(self, key, value)
# ...

# %%
import pandas as pd
from tqdm import tqdm
import re

df = pd.DataFrame(columns=('title', "article")) 
idx = 0
sentiments = []  # 각 문장의 감성 값을 저장할 리스트
extracted_words = []  # 각 기사에서 추출된 단어를 저장할 리스트

# 전체 데이터프레임의 길이만큼 반복
for i in tqdm(range(len(df_2012['new_sentences']))):  
    title = df_2012['title'][i]
    article = df_2012['new_sentences'][i]  # 현재 행의 문장 리스트
    sentence_sentiments = []  # 각 문장의 감성 값 리스트 초기화
    for sentence in article:  # 문장 리스트에서 각 문장에 대해 반복
        sentence_sentiment = 0  # 문장의 감성 값 초기화
        for j in range(0, len(sentiword_dic)):
            if sentiword_dic.word[j] in sentence:
                sentence_sentiment += int(sentiword_dic.polarity[j])
        sentence_sentiments.append(sentence_sentiment)  # 문장의 감성 값을 리스트에 추가
        # 정규 표현식을 사용하여 '당'으로 끝나는 단어 또는 '의원' 앞에 있는 단어 추출
        words = re.findall(r'\b(\w+당|\w+(?=\s의원)|\w+(?=\s위원)|\w+(?=\s비대위원)|\w+(?=\s위원장)|\w+(?=\s비상대책위원장))', sentence)
        # 추출된 단어 리스트를 하나의 문자열로 변환하여 저장
        extracted_words.append(', '.join(words))
    sentiments.append(sentence_sentiments)  # 문장 리스트의 감성 값 리스트를 전체 감성 값 리스트에 추가

# 데이터프레임에 새로운 열 'sentiments'를 추가하고 sentiments 리스트 할당
df['sentiments'] = sentiments
# 데이터프레임에 새로운 열 'extracted_words'를 추가하고 extracted_words 리스트 할당
df['extracted_words'] = extracted_words
# 결과를 합친 문자열로 이루어진 result 열 생성
df['result'] = df.apply(lambda row: f"{''.join(row['extracted_words'])}, {row['sentiments']}", axis=1)

# 결과 출력
print(df[['title', 'article', 'result']])
# Out:
#   0%|                                                                             | 5/28431 [00:09<14:29:13,  1.83s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 18
#      16 sentence_sentiment = 0  # 문장의 감성 값 초기화
#      17 for j in range(0, len(sentiword_dic)):
# ---> 18     if sentiword_dic.word[j] in sentence:
#      19         sentence_sentiment += int(sentiword_dic.polarity[j])
#      20 sentence_sentiments.append(sentence_sentiment)  # 문장의 감성 값을 리스트에 추가
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# ...

# %%
## 랜덤으로 확인하기
import random

# 랜덤으로 행 선택
random_index = random.randint(0, len(df_2012) - 1)
random_row = df_2012.iloc[random_index]

# 선택된 행의 번호 출력
print("Selected Row Index:", random_index)

# 선택된 행의 new_sentences 열 확인
random_row_new_sentences = random_row['new_sentences']
for sentence in random_row_new_sentences:
    print(sentence)
# Out:
# Selected Row Index: 25712
# ㆍ(2) 경제 민주화 - 공약 비교새누리당과 민주통합당 등 여야가 4·11 총선을 앞두고 서로 약속이나 한 것처럼 ‘경제 민주화’를 기치로 내걸었다.
# 여야 모두 현재의 경제 상황이 민주주의와 거리가 있다고 본 것이다.
# 이명박 정부의 친재벌 정책으로 삼성전자나 현대자동차 등 대기업은 엄청난 이익을 내고 있지만 서민은 고물가, 고실업의 고통에 빠져 있다.
# 이런 경제 난맥을 어떻게 타개할지 구체적인 방법에서는 여야가 큰 차이를 보인다.
# 여당은 현행 틀을 유지하면서 점진적으로 개선하자는 입장이다.
# 야당은 과거 정부에서 도입했다가 폐지·축소한 출자총액제한제(출총제), 금융·산업자본 분리(금산분리) 등 대기업 구조 개편안 등을 들고 나왔다.
# 여야는 ‘민생 안정’ 공약도 내놨다.
# 일자리 창출과 서민 주거 안정 대책에 초점을 맞췄다.
# 직장을 찾지 못한 청년과 퇴직한 50~60대, 치솟는 전셋값에 신음하는 30~40대를 겨냥한 것이다.
# 대기업 정책에 비하면 이들 민생 정책은 대동소이했다.
# ▲ 금융소득 과세는 공감대기업 증세는 시각차민생정책은 차이 없어■ 재벌 개혁엔 여야 극명한 시각차새누리당은 일감 몰아주기 근절과 대기업의 중소기업 영역 진입 금지 등을 주요 공약으로 내세웠다.
# 제도를 바꾸기보다는 대기업의 탈법과 불법을 근절해 중소기업을 보호하는 데 방점이 놓였다.
# 자산 순위 30위 대기업집단에 대한 공정거래위원회의 내부거래 조사를 정기화하고, 부당 내부거래에 대한 법 집행을 강화하는 것이 주요 내용이다.
# 대기업이 중소기업 영역에 무분별하게 진출하는 것을 막고, 집단소송제를 확대하는 방안도 마련했다.
# 하지만 이 정도 공약으로 ‘경제 민주화’를 전면에 내걸기는 미흡한 것 아니냐는 비판이 새누리당 내부에서도 나오고 있다.민주통합당은 중소기업 보호와 함께 대기업의 경제력 집중 자체를 억제하기 위한 정책을 내놓았다.
# 출총제 부활과 순환출자 해소 등이 대표적이다.
# ...

# %%
import pandas as pd
from tqdm import tqdm

df = pd.DataFrame(columns=('title', "article")) 
idx = 0
sentiments = []  # 각 문장의 감성 값을 저장할 리스트

for i in tqdm(range(len(df_2012['new_sentences']))):  # 데이터프레임의 총 행 수만큼 반복
    title = df_2012['title'][i]
    article = df_2012['new_sentences'][i]  # 현재 행의 문장 리스트
    sentence_sentiment = 0  # 각 문장의 감성 값
    for sentence in article:  # 문장 리스트에서 각 문장에 대해 반복
        for j in range(0, len(sentiword_dic)):
            if sentiword_dic.word[j] in sentence:
                sentence_sentiment += int(sentiword_dic.polarity[j])
    sentiments.append(sentence_sentiment)  # 문장의 감성 값을 리스트에 추가

# 데이터프레임에 새로운 열 'sentiments'를 추가하고 sentiments 리스트 할당
df['sentiments'] = sentiments

df
# Out:
# 100%|███████████████████████████████████| 28431/28431 [1:37:35<00:00,  4.86it/s]
#       title article  sentiments
# 0       NaN     NaN         -15
# 1       NaN     NaN         -19
# 2       NaN     NaN           8
# 3       NaN     NaN          -4
# 4       NaN     NaN          -6
# ...     ...     ...         ...
# 28426   NaN     NaN         -16
# 28427   NaN     NaN         -12
# 28428   NaN     NaN         -22
# 28429   NaN     NaN          -5
# 28430   NaN     NaN          -6
#
# [28431 rows x 3 columns]
