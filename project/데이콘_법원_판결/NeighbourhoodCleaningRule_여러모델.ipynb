# %% [markdown]
# # 라이브러리 불러오기

# %%
# ! pip install -U imbalanced-learn scikit-learn

# %%
# ! pip install catboost

# %%
import numpy as np
import pandas as pd
import re
import nltk
# nltk.download('stopwords')
# nltk.download('wordnet')

from nltk.tokenize import TreebankWordTokenizer # 표준 토큰화
from nltk.corpus import stopwords # 불용어 제거
from nltk.stem import WordNetLemmatizer # 기본 형태로 변환
from imblearn.under_sampling import NeighbourhoodCleaningRule # 비대칭이라 사용

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import RidgeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import AdaBoostClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 데이터 불러오기

# %%
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')
submission_df = pd.read_csv('./data/sample_submission.csv')

# %%
display(train_df.head())
display(test_df.head())
# Out:
#            ID         first_party                    second_party  \
# 0  TRAIN_0000   Phil A. St. Amant              Herman A. Thompson
# 1  TRAIN_0001      Stephen Duncan                  Lawrence Owens
# 2  TRAIN_0002   Billy Joe Magwood  Tony Patterson, Warden, et al.
# 3  TRAIN_0003          Linkletter                          Walker
# 4  TRAIN_0004  William Earl Fikes                         Alabama
#
#                                                facts  first_party_winner
# 0  On June 27, 1962, Phil St. Amant, a candidate ...                   1
# 1  Ramon Nelson was riding his bike when he suffe...                   0
# 2  An Alabama state court convicted Billy Joe Mag...                   1
# 3  Victor Linkletter was convicted in state court...                   0
# 4  On April 24, 1953 in Selma, Alabama, an intrud...                   1
#           ID                                        first_party  \
# 0  TEST_0000                                            Salerno
# 1  TEST_0001             Milberg Weiss Bershad Hynes and Lerach
# 2  TEST_0002  No. 07-582\t Title: \t Federal Communications ...
# 3  TEST_0003                                    Harold Kaufman
# 4  TEST_0004                                             Berger
#
#                             second_party  \
# 0                          United States
# 1                          Lexecon, Inc.
# 2  Fox Television Stations, Inc., et al.
# 3                          United States
# 4                                 Hanlon
#
#                                                facts
# 0  The 1984 Bail Reform Act allowed the federal c...
# 1  Lexecon Inc. was a defendant in a class action...
# 2  In 2002 and 2003, Fox Television Stations broa...
# 3  During his trial for armed robbery of a federa...
# 4  In 1993, a magistrate judge issued a warrant a...

# %%
train_df.groupby('first_party_winner').size()
# Out:
# first_party_winner
# 0     829
# 1    1649
# dtype: int64

# %% [markdown]
# # 데이터 전처리

# %%
# 문자 처리
cat_cols = ['first_party', 'second_party', 'facts']

# \b : 단어 경계, W* : 길이가 0이상이고 단어가 아닌 문자, w{1} : 길이가 1인 단어
short_word = re.compile(r'\W*\b\w{1}\b') # 길이가 1인 단어 찾기
tokenizer = TreebankWordTokenizer() # 단어 단위로 토큰화
stopword = stopwords.words('english') # 불용어 리스트 가져오기
lemmatizer = WordNetLemmatizer() # 단어의 기본 형태 가져오기

# %%
vec = CountVectorizer(ngram_range = (1, 2)) # 출현빈도
vec_facts = TfidfVectorizer(ngram_range = (1, 2)) # 단어토큰

# %% [markdown]
# ## 단어 처리

# %%
def prepro1(df, cols, short_word, tokenizer, stopword, lemmatizer):
    first_party_lst = []
    second_party_lst = []
    facts_lst = []
    
    for col in cols:
        df[col] = df[col].str.strip() # 공백 제거
        df[col] = df[col].str.lower() # 소문자로 변경
        df[col] = df[col].str.replace(',', '')
        df[col] = df[col].str.replace('.', '')
        
        if col == 'first_party':
            for content in df[col]:
                content = short_word.sub('', content) # 한 글자 단어 제거
                com = re.compile(r"[^\uAC00-\uD7A30-9a-zA-Z\s]") # 한글, 영어, 숫자 및 공백 문자를 제외한 모든 문자를 매칭
                content = com.sub('', content)
                tokens = tokenizer.tokenize(content) # 단어 토큰화
                token_lst = []
                for token in tokens:
                    if token not in stopword: #불용어 제거
                        token_lst.append(lemmatizer.lemmatize(token, 'n')) # 단어의 기본 형태 가져오기
                first_party_lst.append(token_lst)
            # 단어들 결합
            for i in range(len(first_party_lst)):
                first_party_lst[i] = ' '.join(first_party_lst[i])
                
        elif col == 'second_party':
            for content in df[col]:
                content = short_word.sub('', content) # 한 글자 단어 제거
                com = re.compile(r"[^\uAC00-\uD7A30-9a-zA-Z\s]") # 한글, 영어, 숫자 및 공백 문자를 제외한 모든 문자를 매칭
                content = com.sub('', content)
                tokens = tokenizer.tokenize(content) # 단어 토큰화
                token_lst = []
                for token in tokens:
                    if token not in stopword: #불용어 제거
                        token_lst.append(lemmatizer.lemmatize(token, 'n')) # 단어의 기본 형태 가져오기
                second_party_lst.append(token_lst)
            # 단어들 결합
            for i in range(len(second_party_lst)):
                second_party_lst[i] = ' '.join(second_party_lst[i])
                
        elif col == 'facts':
            for content in df[col]:
                content = short_word.sub('', content) # 한 글자 단어 제거
                com = re.compile(r"[^\uAC00-\uD7A30-9a-zA-Z\s]") # 한글, 영어, 숫자 및 공백 문자를 제외한 모든 문자를 매칭
                content = com.sub('', content)
                tokens = tokenizer.tokenize(content) # 단어 토큰화
                token_lst = []
                for token in tokens:
                    if token not in stopword: #불용어 제거
                        token_lst.append(lemmatizer.lemmatize(token, 'n')) # 단어의 기본 형태 가져오기
                facts_lst.append(token_lst)
            # 단어들 결합
            for i in range(len(facts_lst)):
                facts_lst[i] = ' '.join(facts_lst[i])
                
    return first_party_lst, second_party_lst, facts_lst

# %% [markdown]
# ## 벡터화

# %%
def prepro2(first, second, facts, vec, vec_facts, is_train):
    if is_train:
        vec.fit(first + second) # conut
        vec_facts.fit(facts) # Tf
    
    X_first = vec.transform(first).toarray()
    X_second = vec.transform(first).toarray()
    X_facts = vec_facts.transform(facts).toarray()
    
    return np.concatenate([X_first, X_second, X_facts], axis = 1)

# %% [markdown]
# 전처리 실행

# %%
train_first, train_second, train_facts = prepro1(train_df, cat_cols, short_word, tokenizer, stopword, lemmatizer)
test_first, test_second, test_facts = prepro1(test_df, cat_cols, short_word, tokenizer, stopword, lemmatizer)

# %%
train_first
# Out:
# ['phil st amant',
#  'stephen duncan',
#  'billy joe magwood',
#  'linkletter',
#  'william earl fikes',
#  'carbone inc et al',
#  'david jennings et al',
#  'u airway inc',
#  'ron davis acting warden',
#  'paul mcdaniel',
#  'fall city industry inc',
#  'allen et al',
#  'first unitarian church los angeles',
#  'james obergefell et al',
#  'james thole et al',
#  'pierce county',
#  'plyler',
#  'steven spear',
#  'united state',
#  'delbert williamson et al',
#  'clay',
#  'bassam yacoub salman',
#  'organized village kake angoon community association',
#  'edward malley rhode island',
#  'charles wilkie et al',
#  'tennessee valley authority',
#  'united state',
#  'american express et al',
#  'winston holloway et al',
#  'verlinden',
#  'united hauler association inc et al',
#  'united state',
#  'eric thompson',
#  'gerald martin et ux',
#  'jeanne woodford et al',
#  'caterpillar inc',
#  'nix',
#  'kingsley book inc et al',
#  'william erickson',
#  'beacon theatre inc',
#  'allison engine co inc et al',
#  'alabama democratic conference et al',
#  'terrence byrd',
#  'national association manufacturer',
#  'gooding',
#  'china agritech inc',
#  'alberto gonzales attorney general',
#  'cook',
#  'irving independent school district',
#  'phillips',
#  'john kowalski judge 26th judicial circuit court michigan et al',
#  'jose antonio lopez',
#  'terry michael honeycutt',
#  'hicklin',
#  'martinez',
#  'albert ohralik',
#  'randall white',
#  'ec term year trust',
#  'bowman transportation inc et al',
#  'casimir czyzewski et al',
#  'united state',
#  'abbate',
#  'menominee indian tribe wisconsin',
#  'heart atlanta motel inc',
#  'jason mont',
#  'home depot usa inc',
#  'clarence williams',
#  'edith jones et al behalf class others similarly situated',
#  'john sturgeon',
#  'eastland',
#  'texas dept housing community affair et al',
#  'price',
#  'director revenue missouri',
#  'hughes aircraft company',
#  'philip morris usa',
#  'robert wittman et al',
#  'penry',
#  'united state steel corporation',
#  'home visiting nurse service inc',
#  'leiter mineral inc',
#  'ibp inc',
#  'jeffrey beard secretary pennsylvania department correction',
#  'fred shuttlesworth',
#  'strickler',
#  'united state',
#  'florida',
#  'brown',
#  'ida phillips',
#  'gerald mitchell',
#  'csx transportation inc',
#  'andrew winston sheriff et al',
#  'toyota manufacturing kentucky inc',
#  'bridget hardt',
#  'united state',
#  'atkins',
#  'united state',
#  'edward',
#  'edward dorsey sr',
#  'terrance williams',
#  'board curator university missouri',
#  'wisconsin',
#  'andre martello barton',
#  'hudson',
#  'lindh',
#  'jim garrison',
#  'meyer',
#  'timothy tyrone foster',
#  'avondale lockhart',
#  'maryland committee fair representation',
#  'wisconsin',
#  'city los angeles',
#  'long island care home ltd et al',
#  'mccleskey',
#  'office personnel management',
#  'massachusetts',
#  'greg mcquiggin warden',
#  'shaw',
#  'ed plaut et al',
#  'james kisor',
#  'federal election commission',
#  'united state',
#  'california',
#  'simon rodriguez',
#  'endrew',
#  'garner',
#  'arizona free enterprise club freedom club pac et al',
#  'lynwood hall et ux',
#  'slack',
#  'jalil abdulkabir fka ted calvin cole',
#  'southeastern promotion ltd',
#  'booth',
#  'zurcher',
#  'kristina box commissioner indiana department health et al',
#  'martinez',
#  'russell frisby et al',
#  'doyle randall paroline',
#  'michael sole secretary florida department environmental protection et al',
#  'john greenholtz',
#  'merit management group',
#  'region hospital',
#  'school district abington township pennsylvania',
#  'california public employee retirement system',
#  'united state ex rel irwin eisenstein',
#  'national association advancement colored people',
#  'general dynamic land system inc',
#  'arthur james lomax',
#  'exxon company usa',
#  'roy cooper governor north carolina et al',
#  'junius irving scale',
#  'federal election commission',
#  'supreme court new hampshire',
#  'u department transportation et al',
#  'reynoldsville casket co et al',
#  'republic iraq',
#  'perry education association',
#  'federal republic germany et al',
#  'chicago',
#  'lilly ledbetter',
#  'lawrence golan et al',
#  'swann',
#  'mike stanton',
#  'kathleen sebelius secretary health human service',
#  'williams',
#  'communist party indiana et al',
#  'donald trump president united state et al',
#  'gray',
#  'jones',
#  'grupo dataflux',
#  'united state',
#  'kansa',
#  'hustler magazine inc',
#  'brett jones',
#  'johnson',
#  'wilson',
#  'united state',
#  'javier cavazos acting warden',
#  'doug waddington superintendent washington correction center',
#  'oxford health plan',
#  'nathan jackson',
#  'gilvie',
#  'north carolina board dental examiner',
#  'curtis lee kyles',
#  'robert rucho et al',
#  'little sister poor saint peter paul home',
#  'rodney class',
#  'danny escobedo',
#  'derrick kimbrough',
#  'luis nieves et al',
#  'allen',
#  'united state',
#  'loji sale inc',
#  'salman khade abuelhawa',
#  'richard gordon member independent investor protection league',
#  'robert davis',
#  'dana robert',
#  'oregon',
#  'ohio',
#  'harrah independent school district et al',
#  'mary berghuis warden',
#  'richard mathis',
#  'epic system corporation',
#  'united state',
#  'barclay bank plc',
#  'barnes',
#  'pennsylvania',
#  'janet yellen secretary treasury',
#  'smith',
#  'united state',
#  'emanuel brown',
#  'bogan',
#  'william pounder judge',
#  'lopez',
#  'state washington',
#  'city boerne',
#  'john brady',
#  'oregon',
#  'millerel',
#  'albert florence',
#  'wooley',
#  'reno',
#  'marcus sykes',
#  'federal election commission',
#  'gregory',
#  'minerva surgical inc',
#  'shelby county alabama',
#  'burch',
#  'calcanomartinez et al',
#  'raymond haynes',
#  'john toll president university maryland',
#  'tom elli robert love',
#  'metromedia inc et al',
#  'united state',
#  'reno',
#  'benni',
#  'jones',
#  'cyrus vance secretary state et al',
#  'porter',
#  'jeffrey beck liquidating trustee estate crown vantage inc crown paper company',
#  'edna smith primus',
#  'priscilla summer et al',
#  'richard shapero',
#  'george wyman commissioner state new york department social service',
#  'national socialist party america',
#  'crawfordel',
#  'lane',
#  'united state et al',
#  'randy curtis bullock',
#  'rush prudential hmo inc',
#  'new york',
#  'kellogg brown root service inc',
#  'sattazahn',
#  'northeastern florida chapter associated general contractor america',
#  'san remo hotel lp et al',
#  'irwin',
#  'united state',
#  'rosenberger',
#  'allen ryan alleyne',
#  'national association home builder et al',
#  'raymond lucia et al',
#  'freedman',
#  'booth',
#  'harris',
#  'turner broadcasting system inc',
#  'brian coleman superintendant state correctional institution fayette et al',
#  'james walker warden et al',
#  'lamb chapel',
#  'roman',
#  'helen maxine levi travis',
#  'national park hospitality assn',
#  'united state',
#  'chase bank usa na',
#  'printz',
#  'town greece ny',
#  'maryland',
#  'bell',
#  'morse',
#  'grable son metal product inc',
#  'gutierrez',
#  'crystal monique lightfoot et al',
#  'w kirkpatrick company inc',
#  'united state',
#  'village schaumburg',
#  'carlsbad technology inc',
#  'torrey dale grady',
#  'university pennsylvania',
#  'sca hygiene product aktiebolag et al',
#  'vacco',
#  'raines',
#  'water',
#  'united state',
#  'roland camara',
#  'commonwealth virginia',
#  'austin',
#  'francis lorenzo',
#  'robert mcdonald',
#  'paul davis',
#  'air wisconsin airline corporation',
#  'ohio',
#  'minnesota',
#  'united state',
#  'united state',
#  'tuggle',
#  'reverend e evans et al',
#  'commissioner internal revenue',
#  'michael wearry',
#  'lambert',
#  'desert palace inc',
#  'irving jerome dunaway',
#  'mckune',
#  'chaunt',
#  'sonny perdue governor georgia et al',
#  'bryce harlow alexander butterfield',
#  'juan esquivelquintana',
#  'foley',
#  'ward',
#  'united state',
#  'james logan',
#  'carolyn kloeckner',
#  'ohler',
#  'department transportation et al',
#  'james benjamin puckett',
#  'mccreary county kentucky et al',
#  'milliken',
#  'williams',
#  'mcintyre',
#  'vance plumhoff',
#  'united state',
#  'asid mohamad et al',
#  'city los angeles department water power et al',
#  'terry',
#  'nacirema operating co inc liberty mutual insurance company',
#  'united state',
#  'united state',
#  'construction company',
#  'state kansa',
#  'lady guadalupe school',
#  'holmes group inc',
#  'jesus hernndez et al',
#  'bond',
#  'new york',
#  'dan mckaskle acting director texas department correction',
#  'rogers morton secretary interior et al',
#  'city chicago',
#  'united state',
#  'william grady district attorney dutch county',
#  'william crawford et al',
#  'richlin security service company',
#  'michael watson',
#  'united state',
#  'apodaca',
#  'vaughan',
#  'randy white warden',
#  'illinois',
#  'inyo county california',
#  'wisconsin central ltd et al',
#  'timothy scott',
#  'lopez',
#  'midcon freight system inc et al',
#  'arthur andersen llp',
#  'bates',
#  'lester ray nichols',
#  'atlantic marine construction company',
#  'rhode island',
#  'gitlitz',
#  'ronald rompilla',
#  'national cable telecommunication association et al',
#  'city philadelphia et al',
#  'cleveland',
#  'shannon nelson louis alonzo madden',
#  'first english evangelical lutheran church glendale',
#  'neal',
#  'new york',
#  'price waterhouse',
#  'tc heartland llc',
#  'united state',
#  'fane lozman',
#  'goldman sachs group inc et al',
#  'carman deck',
#  'bolivarian republic venezuela et al',
#  'wilson',
#  'bowsher',
#  'united state',
#  'jdb',
#  'stenberg',
#  'metro broadcasting inc',
#  'otis bowen secretary health human service',
#  'commissioner internal revenue',
#  'marvin peugh',
#  'linda lingle governor hawaii et al',
#  'richard allen culbertson',
#  'michael milkovich',
#  'united state',
#  'ginsberg',
#  'david kappos secretary commerce intellectual property director patent trademark office',
#  'lord landing village condominium council unit owner',
#  'ksr international co',
#  'dennis burnham',
#  'vincent joseph spano',
#  'merck kgaa',
#  'kentucky retirement system et al',
#  'united state',
#  'hazelwood school district',
#  'alphonso james jr',
#  'eugene griffin et al',
#  'department homeland security',
#  'colonnade catering corporation',
#  'jan hamilton chapter 13 trustee',
#  'howard delivery service inc et al',
#  'gray',
#  'saint francis college',
#  'csx transportation inc',
#  'lemon',
#  'ornelas',
#  'american national red cross',
#  'american prosperity foundation',
#  'sprint communication co lp',
#  'federal communication commission et al',
#  'albert holland',
#  'kp permanent makeup inc',
#  'shaun michael bosse',
#  'united state',
#  'watchtower bible tract soc new york inc',
#  'zelman',
#  'illinois',
#  'archer',
#  'federal trade commission',
#  'dollar general corporation et al',
#  'genovevo salina',
#  'new york',
#  'texas',
#  'gregory greer',
#  'agostini',
#  'kent',
#  'michael donald dodd',
#  'earl enmund',
#  'ruben floresvillar',
#  'terry brice horton',
#  'national federation federal employee local 1309',
#  'andrew cuomo attorney general new york',
#  'national aeronautics space administration',
#  'ashcroft',
#  'illinois',
#  'new york state board election et al',
#  'calderon',
#  'brown shoe company inc',
#  'cheryl pliler warden',
#  'unitherm food system inc',
#  'city ladue',
#  'amgen inc et al',
#  'federal power commission',
#  'american dredging company',
#  'edward jerome harbison',
#  'stephen mcfadden',
#  'derrick morgan',
#  'butler',
#  'rick perry governor texas et al',
#  'doug dretke director texas department criminal justice correctional institution division',
#  'joseph matal interim director uspto',
#  'samuel lewis director arizona department correction et al',
#  'bacchus import ltd',
#  'united state',
#  'ramdass',
#  'david leon riley',
#  'commonwealth puerto rico et al',
#  'jon husted',
#  'otis bowen secretary health human service john block secretary agriculture walter cohen secretary pennsylvania department public welfare',
#  'national association advancement colored people',
#  'united state',
#  'louis bullard',
#  'jonathan dale simmons',
#  'keith bowles',
#  'eddie thomas',
#  'linda watters commissioner michigan office insurance financial service',
#  'harmelin',
#  'alberto gonzales attorney general',
#  'rentcenter west inc',
#  'charles borden jr',
#  'illinois',
#  'john lascaris commissioner dept social service onondaga county',
#  'clifton sandifer et al',
#  'washington',
#  'auer',
#  'doctor associate inc',
#  'cook county',
#  'united state',
#  'fort bend county texas',
#  'russell bucklew',
#  'pruneyard shopping center',
#  'keith haywood',
#  'mitchell',
#  'hartehanks communication inc',
#  'american tradition partnership inc',
#  'lopez',
#  'board ed independent school dist 92 pottawatomie cty',
#  'zuni public school district 89 et al',
#  'conn',
#  'corporation',
#  'amgen inc kevin sharer richard nanula roger perlmutter george morrow',
#  'estate burton kanter deceased et al',
#  'term limit inc',
#  'adderley',
#  'burlington industry inc',
#  'michael fitzgerald treasurer iowa',
#  'gravel',
#  'pacific bell telephone co',
#  'ruhrgas ag',
#  'buckhannon board care home inc',
#  'united state america',
#  'walker',
#  'harry slochower',
#  'marcelo manrique',
#  'anthony perry',
#  'roderick jackson',
#  'kenneth salazar et al',
#  'woodford',
#  'kelly harrington warden',
#  'exxon corporation',
#  'donald vale',
#  'christine armour',
#  'jay hein director white house office faithbased community initiative et al',
#  'mickens',
#  'arkansas department health human service et al',
#  'northern pipeline constr company',
#  'lachance',
#  'middleton',
#  'stoneridge investment partner llc',
#  'pliva inc et al',
#  'doug decker official capacity oregon state forester et al',
#  'louisiana',
#  'david bobby warden',
#  'ruth elizabeth chapman thomas leroy teale',
#  'cox broadcasting corporation',
#  'highmark inc',
#  'board education oklahoma city public school',
#  'alaska',
#  'john roemer iii et al',
#  'barenblatt',
#  'united state',
#  'medtronic inc',
#  'city arlington tx city san antonio tx',
#  'united state',
#  'illinois',
#  'james mcwilliams',
#  'texas',
#  'ellen schall commissioner new york city department juvenile justice',
#  'larry witters',
#  'leh',
#  'pointer',
#  'kerri kaley brian kaley',
#  'deneice mayle warden',
#  'anthony ray hinton',
#  'randal rush et al',
#  'east river steamship corporation',
#  'national labor relation board',
#  'riverside county',
#  'koons buick pontiac gmc inc',
#  'board regent university wisconsin system',
#  'thryv inc',
#  'environmental protection agency et al',
#  'compucredit corporation et al',
#  'hudson et al',
#  'jbconnor md',
#  'textron lycoming',
#  'barnhart',
#  'jasper williams et al',
#  'exxon mobil corporation',
#  'hotel employee union local 255',
#  'suitum',
#  'united state',
#  'shaw',
#  'massachusetts et al',
#  'gregg',
#  'united state',
#  'judson griffin james crenshaw',
#  'gil garcetti et al',
#  'husky international electronics inc',
#  'hardware inc',
#  'citizen bank',
#  'new york state club association inc',
#  'keith tharpe',
#  'joseph mckeiver et al',
#  'tara sheneva williams',
#  'engine manufacturer association western state petroleum association',
#  'rogers',
#  'united state',
#  'sd warren company',
#  'united state',
#  'eli lilly company',
#  'stewart',
#  'fullilove',
#  'northwest inc et al',
#  'american textile manufacturer institute inc et al',
#  'united state',
#  'shady grove orthopedic associate pa',
#  'meyer',
#  'cleveland board education chesterfield county school board dr robert kelly',
#  'griggs',
#  'melendez',
#  'charles russell rhine',
#  'jeffrey chafin',
#  'polar tanker inc',
#  'donald trump president united state et al',
#  'security exchange commission',
#  'new york',
#  'carlos jimenez',
#  'united state',
#  'reginald shepard',
#  'morgan stanley capital group inc',
#  'state oil company',
#  'lewis',
#  'joel sereboff et ux',
#  'united state',
#  'united state',
#  'parker drilling management service ltd',
#  'united state',
#  'percy dillon',
#  'jim yovino fresno county superintendent school',
#  'cardinal chemical company',
#  'american radio assn aflcio et al',
#  'john sand gravel company',
#  'robinson',
#  'dell',
#  'ellen goett administratrix estate marvin paul goett',
#  'rankin',
#  'lujan',
#  'united jewish organization williamsburgh inc',
#  'shafer',
#  'yarborough',
#  'robinson',
#  'richard cheney vice president united state et al',
#  'earl deen',
#  'tennessee student assistance corporation',
#  'robert brady',
#  'missouri',
#  'arizona',
#  'jae lee',
#  'hortonville independent school district et al',
#  'lapides',
#  'los angeles county flood control distric',
#  'deal',
#  'comcast corp et al',
#  'helen purcell maricopa county recorder et al',
#  'james ziglar',
#  'curtis flood',
#  'ralph baze thomas bowling',
#  'william milliken governor michigan et al',
#  'rutledge',
#  'young',
#  'united state',
#  'friend earth inc',
#  'united state et al',
#  'estate thornton',
#  'nidal khalid nasrallah',
#  'dorsie lee johnson jr',
#  'timmons',
#  'chike uzuegbunam et al',
#  'arizona et al',
#  'michael',
#  'american trucking association inc',
#  'talk america inc',
#  'david pasquantino carl pasquantino arthur hilt',
#  'abby gail lassiter',
#  'peter aaron',
#  'franklin',
#  'rostker',
#  'byrd',
#  'federal communication commission',
#  'ricky henson et al',
#  'midland funding llc',
#  'united state',
#  'gilbert president east stroudsburg university et al',
#  'jason pepper',
#  'steven engel et al',
#  'utah',
#  'jerry douglas mempa',
#  'associate commercial corp',
#  'board regent state college',
#  'koon',
#  'alliedbruce terminix co',
#  'john graham commissioner department public welfare state arizona',
#  'board airport commissioner city los angeles',
#  'united state',
#  'massachusetts',
#  'john geddes lawrence tyron garner',
#  'mobile south llc',
#  'weyerhaeuser company',
#  'mitchell',
#  'american insurance as',
#  'elliott hibbs director arizona department revenue',
#  'brown',
#  'norton anthony russell',
#  'integrity staffing solution inc',
#  'roell',
#  'merck co inc et al',
#  'united state',
#  'corporation presiding bishop church jesus christ latterday saint',
#  'houchins',
#  'humana inc',
#  'basic incorporated et al',
#  'furman',
#  'lucky brand dungaree inc et al',
#  'jeffrey richard robbins',
#  'ian calder john south',
#  'parent guardian ari zivotofsky et ux',
#  'richard erznoznik',
#  'john lamie',
#  'russell runyon et al',
#  'united state',
#  'bridget anne kelly',
#  'rimini street inc et al',
#  'reno',
#  'general dynamic corporation',
#  'boo',
#  'charles turner et al',
#  'interstate commerce commission',
#  'aetna health inc fka aetna u healthcare inc aetna u healthcare north texas inc',
#  'roxanne torres',
#  'giridhar sekhar',
#  'state ohio et al',
#  'clemente avelino pereida',
#  'winston massiah',
#  'jeffrey wood',
#  'grogan',
#  'edward lane',
#  'traveler casualty surety company america',
#  'burlington northern santa fe railway company',
#  'javan owen daniel lessard',
#  'microsoft corporation',
#  'loving',
#  'northwest austin municipal utility district number one',
#  'howsam',
#  'william schwab',
#  'lockett',
#  'abf freight system inc',
#  'george samuel abraham taylor herman benjamin ferguson arthur harris mandola mcpherson max stanford merle stewart hampton woodward rookard ursula virginia west milton elli',
#  'adarand constructor inc',
#  'afroyim',
#  'cedar point nursery et al',
#  'bruce abramski',
#  'limelight network',
#  'stephen voisine et al',
#  'state farm fire casualty co',
#  'greatwest life annuity insurance company',
#  'diamond',
#  'joseph anthony davis',
#  'united state',
#  'wright',
#  'selective service system',
#  'georgia brower et al',
#  'arlington central school district board education',
#  'federal aviation administration',
#  'food marketing institute',
#  'posadas de puerto rico associate dba condado holiday inn',
#  'mclane company inc',
#  'united state',
#  'united state',
#  'county los angeles et al',
#  'utah',
#  'lackawanna county district attorney',
#  'commil usa llc',
#  'daniel locke et al',
#  'michigan',
#  'hazen paper co robert hazen thomas hazen',
#  'maryland',
#  'nollan',
#  'whole woman health et al',
#  'clinton',
#  'karcher',
#  'district columbia et al',
#  'joseph murr et al',
#  'hernanryan castro',
#  'hawaii housing authority',
#  'jane monell et al',
#  'wisconsin department correction',
#  'american trucking association inc',
#  'burlington northern railroad co et al',
#  'panagis vartelas',
#  'matchbenashshewish band pottawatomi indian',
#  'united state',
#  'jefferson county',
#  'butz',
#  'wygant',
#  'stogner',
#  'cic service llc',
#  'ryder',
#  'willie israel alderman',
#  'beck',
#  'florida',
#  'united state',
#  'eldred',
#  'city county san francisco california et al',
#  'chavez',
#  'defunis',
#  'john burrell garner',
#  'john sturgeon',
#  'lloyd corp ltd',
#  'illinois',
#  'caraco pharmaceutical laboratory ltd et al',
#  'kentucky association health plan inc',
#  'donald trump et al',
#  'vl',
#  'united state',
#  'united state',
#  'encino motorcar llc',
#  'smiley',
#  'college saving bank',
#  'planned parenthood central missouri david hall md michael freiman md',
#  'michael kingsley',
#  'yamaha motor corporation usa',
#  'united state',
#  'margaret bradshaw warden',
#  'loving et ux',
#  'david whitfield',
#  'chimel',
#  'kevin smith warden',
#  'united state',
#  'rjr nabisco inc et al',
#  'glen burton ake',
#  'united state',
#  'harry lehman',
#  'michelle monasky',
#  'campbell',
#  'saratoga fishing company',
#  'donald rumsfeld secretary defense et al',
#  'julie heimeshoff',
#  'gregory welch',
#  'walter zant warden georgia diagnostic classification center',
#  'de buono',
#  'kim millbrook',
#  'albert snyder',
#  'hudson',
#  'board trustee leland stanford junior university',
#  'schad',
#  'new york time company',
#  'wharf holding ltd',
#  'minnesota',
#  'ballew',
#  'norfolk southern railway company',
#  'moones mellouli',
#  'merrick garland attorney general',
#  'jeffrey session iii attorney general',
#  'degen',
#  'safeco insurance company america et al',
#  'camp newfoundowatonna inc',
#  'abdusshahid m ali',
#  'marcus burrage',
#  'curtis craig carolyn whitener',
#  'james eric moore',
#  'ppl montana llc',
#  'pga tour inc',
#  'larry gene heath',
#  'maryland',
#  'david carpenter',
#  'world wide volkswagen corp seaway volkswagen inc',
#  'quality king distributor inc',
#  'azel smith et al',
#  'ashbel wall ii director rhode island department correction',
#  'pat osborn',
#  'morrison',
#  'susan jinks',
#  'bay area laundry dry cleaning pension trust fund',
#  'mohammad munaf et al',
#  'yaser esam hamdi esam fouad hamdi next friend yaser esam hamdi',
#  'skinner',
#  'fnu tanzin et al',
#  'virgil gu reichle jr et al',
#  'territory guam',
#  'hoffman plastic compound inc',
#  'calderone',
#  'daniel touby et ux',
#  'homero gonzalez',
#  'norfolk western railway company',
#  'harper row publisher inc',
#  'kent',
#  'schindler elevator corporation',
#  '14 penn plaza llc et al',
#  'pdr network llc et al',
#  'mark sheriff et al',
#  'john joseph killian',
#  'john bridge et al',
#  'brandon thomas betterman',
#  'circuit city store inc',
#  'robert franklin godfrey',
#  'sable communication california',
#  'nevada',
#  'kansa',
#  'ken salazar secretary interior et al',
#  'kevin loughrin',
#  'united state',
#  'john yates',
#  'united state',
#  'lynch',
#  'united state et al',
#  'buchanan',
#  'free enterprise fund beckstead watt llp',
#  'marvin pickering',
#  'marcus thornton',
#  'time inc',
#  'united state',
#  'lawrence joseph jefferson',
#  'california',
#  'peter bret chiafalo levi jennet guerra esther virginia john',
#  'margaret minneci et al',
#  'transunion llc',
#  'national cable telecommunication association',
#  'david randolph gray',
#  'sandy williams',
#  'united state america',
#  'united state',
#  'thompson',
#  'north bd educ',
#  'allen breed director california authority',
#  'steven levin',
#  'pom wonderful llc',
#  'raleigh',
#  'donald carcieri governor rhode island',
#  'kyllo',
#  'keith lavon burgess',
#  'george tenet individually porter go director central intelligence director central intelligence agency united state',
#  'josue leocal',
#  'aurelio gonzalez',
#  'morale attorney general texas',
#  'sibron',
#  'chadha',
#  'georgia',
#  'arthur flemming secretary health education welfare',
#  'u bank national association',
#  'daimler ag',
#  'immigration naturalization service',
#  'mac shell service et al',
#  'willard stewart',
#  'animal science product inc et al',
#  'adaucto chavezmesa',
#  'thomas',
#  'tyson timbs',
#  'williamson county regional planning commission',
#  'arizonan official english',
#  'new york',
#  'green tree financial corporationalabama',
#  'arthur lewis jr et al',
#  'mahan',
#  'bible',
#  'david patchak',
#  'edward et al',
#  'bernard bilski rand warsaw',
#  'janus capital group inc et al',
#  'khanh phuong nguyen',
#  'lewis',
#  'street',
#  'william neil warden tennessee state penitentiary',
#  'pennsylvania state police',
#  'ben ysursa idaho secretary state et al',
#  'beal',
#  'festo corporation',
#  'gary graham',
#  'nicole dalmazzi',
#  'john marshall warden',
#  'united state',
#  'william sorrell attorney general vermont et al',
#  'ohio',
#  'david anthony taylor',
#  'coventry health care missouri inc',
#  'federal election commission',
#  'verizon maryland inc',
#  'penry',
#  'nixon',
#  'schuette',
#  'wood',
#  'ray haluch gravel co et al',
#  'west lynn creamery inc',
#  'richard nixon',
#  'mohawk industry inc',
#  'lisa watson et al',
#  'howard lawn',
#  'geduldig director department human resource development',
#  'hercules inc',
#  'joseph waller jr',
#  'virginia house delegate et al',
#  'robert louis marrama',
#  'douglas spector et al',
#  'dooley',
#  'first national bank arizona',
#  'mike johanns secretary agriculture et al',
#  'united state',
#  'weyerhaeuser company',
#  'brogan',
#  'mcdonnell douglas corporation',
#  'united state',
#  'jones sr et al',
#  'firefighter',
#  'smith',
#  'hosannatabor evangelical lutheran church school',
#  'lutrelle parker acting commissioner patent trademark',
#  'north star steel company',
#  'merrill lynch pierce fenner smith inc',
#  'tarahrick terry',
#  'michigan et al',
#  'gary ewing',
#  'duncan',
#  'lujan',
#  ...]

# %%
X_train = prepro2(train_first, train_second, train_facts, vec, vec_facts, True)
y_train = train_df['first_party_winner']
X_test = prepro2(test_first, test_second, test_facts, vec, vec_facts, False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 X_train = prepro2(train_first, train_second, train_facts, vec, vec_facts, True)
#       2 y_train = train_df['first_party_winner']
#       3 X_test = prepro2(test_first, test_second, test_facts, vec, vec_facts, False)
#
# Cell In[10], line 8, in prepro2(first, second, facts, vec, vec_facts, is_train)
#       6 X_first = vec.transform(first).toarray()
#       7 X_second = vec.transform(first).toarray()
# ----> 8 X_facts = vec_facts.transform(facts).toarray()
#      10 return np.concatenate([X_first, X_second, X_facts], axis = 1)
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_compressed.py:1050, in _cs_matrix.toarray(self, order, out)
#    1048 if out is None and order is None:
#    1049     order = self._swap('cf')[0]
# -> 1050 out = self._process_toarray_args(order, out)
#    1051 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1052     raise ValueError('Output array must be C or F contiguous')
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_base.py:1267, in _spbase._process_toarray_args(self, order, out)
#    1265     return out
#    1266 else:
# -> 1267     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 3.35 GiB for an array with shape (2478, 181605) and data type float64

# %%
print('Train shape : {}, {}'.format(X_train.shape, y_train.shape))
print('Test shape : {}'.format(X_test.shape))
# Out:
# Train shape : (2478, 204261), (2478,)
# Test shape : (1240, 204261)

# %% [markdown]
# ## 불균형 데이터 처리

# %%
X_ncr, y_ncr = NeighbourhoodCleaningRule(kind_sel = "all",  n_neighbors = 5).fit_resample(X_train, y_train)
print('train shape : {}, {}'.format(X_ncr.shape, y_ncr.shape))
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\imblearn\under_sampling\_prototype_selection\_neighbourhood_cleaning_rule.py:201: FutureWarning: `kind_sel` is deprecated in 0.12 and will be removed in 0.14. It already has not effect and corresponds to the `'all'` option.
#   warnings.warn(
# train shape : (1775, 204261), (1775,)

# %%
y_ncr.value_counts()
# Out:
# first_party_winner
# 1    946
# 0    829
# Name: count, dtype: int64

# %% [markdown]
# # 모델링

# %% [markdown]
# ## 데이터 분리

# %% [markdown]
# train데이터 셋으로 train, val 데이터 셋으로 분리

# %%
X_train, X_val, y_train, y_val = train_test_split(X_ncr, y_ncr, random_state = 42, test_size = 0.2, 
                                                 stratify = y_ncr)

print('Train shape : {}, {}'.format(X_train.shape, y_train.shape))
print(y_train.value_counts())

print()

print('Validation shape : {}, {}'.format(X_val.shape, y_val.shape))
print(y_val.value_counts())
# Out:
# Train shape : (1420, 204261), (1420,)
# first_party_winner
# 1    757
# 0    663
# Name: count, dtype: int64
#
# Validation shape : (355, 204261), (355,)
# first_party_winner
# 1    189
# 0    166
# Name: count, dtype: int64

# %%
model_lst = ['Logistic Regression', 'KNN Classifier', 'Decision Tree', 'Random Forest', 'Ridge Claffifier',
            'XGBoost', 'AdaBoost', 'Catboost']

# %%
models = [ LogisticRegression(max_iter = 1000),
                   KNeighborsClassifier(n_neighbors = 149, n_jobs = -1),
                   DecisionTreeClassifier(),
                   RandomForestClassifier(n_estimators = 100),
                   RidgeClassifier(),
                   XGBClassifier(),
                   AdaBoostClassifier(),
                   CatBoostClassifier(verbose = 0, random_state = 113)]

# %%
def score(X_train, y_train, X_val, y_val, names, models):
    score_df = pd.DataFrame()
    score_train_lst = []
    score_val_lst = []
    
    for model in models:
        model.fit(X_train, y_train)
        y_train_pred = model.predict(X_train)
        y_val_pred = model.predict(X_val)
        score_train_lst.append(accuracy_score(y_train, y_train_pred))
        score_val_lst.append(accuracy_score(y_val, y_val_pred))
        
    score_df['model'] = names
    score_df['Train accuracy'] = score_train_lst
    score_df['Validation accuracy'] = score_val_lst
    score_df = score_df.sort_values('Validation accuracy', ascending = False)
    return score_df

# %%
score(X_train, y_train, X_val, y_val, model_lst, models)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
#                  model  Train accuracy  Validation accuracy
# 0  Logistic Regression        1.000000             0.602817
# 4     Ridge Claffifier        1.000000             0.574648
# 3        Random Forest        1.000000             0.549296
# 7             Catboost        0.976761             0.540845
# 5              XGBoost        0.998592             0.532394
# 6             AdaBoost        0.750000             0.498592
# 2        Decision Tree        1.000000             0.490141
# 1       KNN Classifier        0.466901             0.467606

# %% [markdown]
# # 제출

# %%
y_pred  = best_logistic.predict(X_test)
submission_df['first_party_winner'] = y_pred
# submission_df.to_csv('neighbourhoodcleaningrule_logi.csv', index = False)
